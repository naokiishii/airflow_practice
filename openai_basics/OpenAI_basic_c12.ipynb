# %%
# !pip install openai
# !pip install numpy
# !pip install pandas
# !pip install tenacity
# !pip install tiktoken
# Out:
# Collecting openai
#   Downloading openai-1.52.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.52.1-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 10.2 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.3 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 14.1 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 openai-1.52.1
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (9.0.0)
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.2 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.8.0

# %%
import os
import json
import openai
import pandas as pd
import tiktoken
from google.colab import userdata
from tenacity import retry, wait_random_exponential, stop_after_attempt
import pickle

# %% [markdown]
# Environment Variables

# %%
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
client = openai.OpenAI()

# %%
dataset_path = './wiki_movie_plots_deduped.csv'
df = pd.read_csv(dataset_path)

# %%
df
# Out:
#        Release Year                                  Title Origin/Ethnicity  \
# 0              1901                 Kansas Saloon Smashers         American
# 1              1901          Love by the Light of the Moon         American
# 2              1901                The Martyred Presidents         American
# 3              1901       Terrible Teddy, the Grizzly King         American
# 4              1902                 Jack and the Beanstalk         American
# ...             ...                                    ...              ...
# 22320          2013                                   Mama         Canadian
# 22321          2013  The Mortal Instruments: City of Bones         Canadian
# 22322          2013            Please Kill Mr. Know It All         Canadian
# 22323          2013                Rhymes for Young Ghouls         Canadian
# 22324          2013                The Right Kind of Wrong         Canadian
#
#                                  Director  \
# 0                                 Unknown
# 1                                 Unknown
# 2                                 Unknown
# 3                                 Unknown
# 4      George S. Fleming, Edwin S. Porter
# ...                                   ...
# 22320                   Andres Muschietti
# 22321                        Harald Zwart
# 22322       Colin Carter & Sandra Feldman
# 22323                        Jeff Barnaby
# 22324                 Jeremiah S. Chechik
#
#                                                     Cast  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 22320            Jessica Chastain, Nikolaj Coster-Waldau
# 22321  Lily Collins, Jamie Campbell Bower, Robert She...
# 22322             Lara Jean Chorostecki, Jefferson Brown
# 22323              Kawennahere Devery Jacobs, Glen Gould
# 22324         Ryan Kwanten, Will Sasso, Catherine O'Hara
#
#                                   Genre  \
# 0                               unknown
# 1                               unknown
# 2                               unknown
# 3                               unknown
# 4                               unknown
# ...                                 ...
# 22320                            horror
# 22321  action-adventure science fantasy
# 22322                   romantic comedy
# 22323                             drama
# 22324                           romance
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 22320     https://en.wikipedia.org/wiki/Mama_(2013_film)
# 22321  https://en.wikipedia.org/wiki/The_Mortal_Instr...
# 22322  https://en.wikipedia.org/wiki/Please_Kill_Mr._...
# 22323  https://en.wikipedia.org/wiki/Rhymes_for_Young...
# 22324                                         https://en
#
#                                                     Plot
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 22320  Distraught after losing his fortune in the 200...
# 22321  New York City teenager Clary Fray begins seein...
# 22322  Cynical Sally lives a life free of excitement ...
# 22323  The film opens with a brief prologue explainin...
# 22324                                                NaN
#
# [22325 rows x 8 columns]

# %%
movies = df[df['Origin/Ethnicity'] == 'American'].sort_values("Release Year", ascending=False).head(5000)

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def get_embedding(text, model='text-embedding-ada-002'):
  text = text.replace('\n', ' ')
  return client.embeddings.create(input=text, model=model).data[0].embedding

# %%
get_embedding('Hellow World')
# Out:
# [-0.004892924800515175,
#  0.00449153920635581,
#  0.00375511241145432,
#  -0.027705565094947815,
#  -0.012565693818032742,
#  -0.0011477640364319086,
#  -0.0016519840573891997,
#  -0.007032542489469051,
#  -0.01752828061580658,
#  0.0019074113806709647,
#  -0.0024912450462579727,
#  0.004776821471750736,
#  0.008943270891904831,
#  -0.007145328912883997,
#  -0.012705017812550068,
#  0.021323200315237045,
#  0.0008931661141104996,
#  0.02494562231004238,
#  0.008505395613610744,
#  -0.021814150735735893,
#  -0.00455124955624342,
#  -0.0056824274361133575,
#  -0.003834726056084037,
#  -0.0014993911609053612,
#  0.004100105259567499,
#  ...]

# %%
embedding_cache_path = 'movie_embeddings_demo.pkl'

try:
  embedding_cache = pd.read_pickle(embedding_cache_path)
except FileNotFoundError:
  embedding_cache = {}
with open(embedding_cache_path, 'wb') as embedding_cache_file:
  pickle.dump(embedding_cache, embedding_cache_file)

def embedding_from_string(
    string,
    model='text-embedding-ada-002',
    embedding_cache=embedding_cache
):
  if (string, model) not in embedding_cache.keys():
    embedding_cache[(string, model)] = get_embedding(string, model)
    print(f'GOT EMBEDDING FOR {string[:20]}')
    with open(embedding_cache_path, 'wb') as embedding_cache_file:
      pickle.dump(embedding_cache, embedding_cache_file)
  return embedding_cache[(string, model)]

# %%
embedding_from_string('Chicken is friend')
# Out:
# [-0.002181887859478593,
#  -0.012682124972343445,
#  -0.012019905261695385,
#  -0.013831637799739838,
#  0.005219662562012672,
#  -0.006125528831034899,
#  -0.017867427319288254,
#  -0.02558915503323078,
#  -0.010776682756841183,
#  -0.030786952003836632,
#  0.004804213996976614,
#  0.005282136145979166,
#  0.005147818010300398,
#  0.005066602490842342,
#  -0.021940700709819794,
#  0.010732950642704964,
#  0.0468551404774189,
#  -0.00789040606468916,
#  0.031211771070957184,
#  -0.027563318610191345,
#  -0.03433544933795929,
#  0.008790024556219578,
#  -0.00725942337885499,
#  -0.024714525789022446,
#  -0.0022834071423858404,
#  0.02851291559636593,
#  0.011463891714811325,
#  -0.035010162740945816,
#  0.00947723351418972,
#  -0.00252080662176013,
#  0.03940829634666443,
#  -0.002792566316202283,
#  0.0011151523794978857,
#  0.008027847856283188,
#  -0.008914971724152565,
#  -0.010039495304226875,
#  0.003147103590890765,
#  -0.0008785339305177331,
#  0.01784243807196617,
#  0.0005708517855964601,
#  0.035310033708810806,
#  -0.004548072349280119,
#  -0.007171960547566414,
#  0.0009371028281748295,
#  -0.023877380415797234,
#  0.009920795448124409,
#  0.015006139874458313,
#  -0.012019905261695385,
#  -0.01896696165204048,
#  -0.00024852747446857393,
#  0.021553365513682365,
#  0.00410451041534543,
#  -0.012719608843326569,
#  -0.011707537807524204,
#  -0.01641804166138172,
#  0.04168233275413513,
#  -0.011438901536166668,
#  0.014181489124894142,
#  0.004117005039006472,
#  -0.0012861735885962844,
#  0.00631607323884964,
#  -0.0010604880517348647,
#  -0.02873782068490982,
#  0.032961029559373856,
#  -0.007634264416992664,
#  0.01273210346698761,
#  0.001664919313043356,
#  -0.0075030699372291565,
#  0.004807337652891874,
#  0.023065224289894104,
#  0.023565012961626053,
#  0.010707961395382881,
#  -0.024914439767599106,
#  -0.008027847856283188,
#  -0.007553048897534609,
#  -0.002016332931816578,
#  -0.0035891039296984673,
#  -0.020116474479436874,
#  0.012607156299054623,
#  -0.0004970549489371479,
#  -0.01710524968802929,
#  -0.000635668111499399,
#  0.028088094666600227,
#  -0.018517151474952698,
#  -0.020203936845064163,
#  -2.462335214659106e-05,
#  0.0013642655685544014,
#  0.024739515036344528,
#  0.01100783422589302,
#  -0.024089790880680084,
#  -0.01976662315428257,
#  0.0010464314837008715,
#  -0.022552940994501114,
#  0.007752964273095131,
#  -0.016655441373586655,
#  -0.01852964609861374,
#  -0.0026926088612526655,
#  -0.0008394879405386746,
#  0.0009230462601408362,
#  0.003664072137326002,
#  0.23110204935073853,
#  -0.008989939466118813,
#  0.010151946917176247,
#  0.023465054109692574,
#  -0.021228503435850143,
#  0.017167724668979645,
#  -0.0014993645017966628,
#  0.006175507791340351,
#  0.0021194142755120993,
#  0.00425757048651576,
#  0.002850354416295886,
#  0.009695890359580517,
#  -0.008783777244389057,
#  0.010564272291958332,
#  0.005285259801894426,
#  0.024427147582173347,
#  -0.02393985353410244,
#  -0.0031627221032977104,
#  -0.005606998689472675,
#  -0.04075772687792778,
#  0.020328884944319725,
#  -0.007096991874277592,
#  -0.013906605541706085,
#  0.006353557109832764,
#  -0.0016602338291704655,
#  0.020928630605340004,
#  -0.03655950352549553,
#  -0.013631722889840603,
#  0.02525179833173752,
#  -0.002213124418631196,
#  -0.02097860909998417,
#  -0.012069884687662125,
#  0.001699279760941863,
#  -0.013619227334856987,
#  -0.002620764309540391,
#  0.0026285734493285418,
#  0.005179055035114288,
#  -0.010114463046193123,
#  0.012713361531496048,
#  0.003892100416123867,
#  0.014268952421844006,
#  -0.009795848280191422,
#  0.019404275342822075,
#  0.004198220558464527,
#  0.008939960971474648,
#  0.0073406388983130455,
#  ...]

# %%
movie_plots = movies['Plot'].values

# %%
enc = tiktoken.encoding_for_model('text-embedding-ada-002')

# %%
total_tokens = sum([ len(enc.encode(plot)) for plot in movie_plots])

# %%
total_tokens
cost = total_tokens * (.0004 / 1000)
print(f'Estimated cost ${cost:.2f}')
# Out:
# Estimated cost $1.45

# %%
plot_embeddings = [embedding_from_string(plot, model='text-embedding-ada-002') for plot in movie_plots]
# Out:
# GOT EMBEDDING FOR In 1954 London, reno
# GOT EMBEDDING FOR Eighteen-year-old Ma
# GOT EMBEDDING FOR In a prologue, busin
# GOT EMBEDDING FOR Anne (Diane Lane) is
# GOT EMBEDDING FOR During the Iraq War,
# GOT EMBEDDING FOR A contemporary tale
# GOT EMBEDDING FOR Recently fired from
# GOT EMBEDDING FOR The movie opens with
# GOT EMBEDDING FOR Mary (Debra Winger)
# GOT EMBEDDING FOR In 2014, Peter Quill
# GOT EMBEDDING FOR A young street magic
# GOT EMBEDDING FOR Having made a career
# GOT EMBEDDING FOR When her car breaks
# GOT EMBEDDING FOR Mikael (Oscar Isaac)
# GOT EMBEDDING FOR Julia Banks is being
# GOT EMBEDDING FOR This documentary fol
# GOT EMBEDDING FOR Best friends Mindy (
# GOT EMBEDDING FOR Dash (voiced by Schw
# GOT EMBEDDING FOR Ireland, 1905: Percy
# GOT EMBEDDING FOR Thirteen years ago,
# GOT EMBEDDING FOR Dominic "Dom" Torett
# GOT EMBEDDING FOR Roman Melnyk, a cons
# GOT EMBEDDING FOR In a small town near
# GOT EMBEDDING FOR Gloria is an unemplo
# GOT EMBEDDING FOR Joe, Willie, and Alb
# GOT EMBEDDING FOR One year after the p
# GOT EMBEDDING FOR The story is told fr
# GOT EMBEDDING FOR In 1980, atheist and
# GOT EMBEDDING FOR In Emerald Bay, Flor
# GOT EMBEDDING FOR During their visit t
# GOT EMBEDDING FOR Former villain Gru i
# GOT EMBEDDING FOR In 2007, self-define
# GOT EMBEDDING FOR Baby is a getaway dr
# GOT EMBEDDING FOR In an unspecified ne
# GOT EMBEDDING FOR Kumail is a comedian
# GOT EMBEDDING FOR Martha Farnsworth ru
# GOT EMBEDDING FOR In 484 AD, King Arth
# GOT EMBEDDING FOR In a small suburban
# GOT EMBEDDING FOR Lisa (Mandy Moore) a
# GOT EMBEDDING FOR At the Clinton Corre
# GOT EMBEDDING FOR In 2006, four friend
# GOT EMBEDDING FOR Lightning McQueen, n
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Megan Leavey is a US
# GOT EMBEDDING FOR After the young boy
# GOT EMBEDDING FOR A highly contagious
# GOT EMBEDDING FOR In 1157 A.D., severa
# GOT EMBEDDING FOR Dean (Demetri Martin
# GOT EMBEDDING FOR In the city of Piqua
# GOT EMBEDDING FOR In present-day Paris
# GOT EMBEDDING FOR In the summer of 200
# GOT EMBEDDING FOR Twelve-year-old Henr
# GOT EMBEDDING FOR In Smurf Village, th
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR While holding a cryi
# GOT EMBEDDING FOR Young Gitty, an 11-y
# GOT EMBEDDING FOR At a large financial
# GOT EMBEDDING FOR Searching for the se
# GOT EMBEDDING FOR Four days after the
# GOT EMBEDDING FOR After Anastasia Stee
# GOT EMBEDDING FOR Within the Lego Univ
# GOT EMBEDDING FOR Growing Up Smith is
# GOT EMBEDDING FOR A man is tasked with
# GOT EMBEDDING FOR In the near future,
# GOT EMBEDDING FOR On an airplane bound
# GOT EMBEDDING FOR Living in a gang rid
# GOT EMBEDDING FOR Dr. James Marcus, th
# GOT EMBEDDING FOR In the 1950s, a fera
# GOT EMBEDDING FOR Set in the autumn of
# GOT EMBEDDING FOR To give a better fut
# GOT EMBEDDING FOR Former child star Ga
# GOT EMBEDDING FOR NSA Agent Augustus G
# GOT EMBEDDING FOR Casey Cooke is an em
# GOT EMBEDDING FOR After the accidental
# GOT EMBEDDING FOR The film centers on
# GOT EMBEDDING FOR In Las Vegas, vice L
# GOT EMBEDDING FOR In 1969, a mass murd
# GOT EMBEDDING FOR Terravex Oil is in t
# GOT EMBEDDING FOR The remaining vampir
# GOT EMBEDDING FOR It is the last day b
# GOT EMBEDDING FOR Directed by Sofia Ca
# GOT EMBEDDING FOR In February, at a pr
# GOT EMBEDDING FOR Sarah (Riley Keough)
# GOT EMBEDDING FOR Dr. Jan Żabiński (Jo
# GOT EMBEDDING FOR A man named Tim Temp
# GOT EMBEDDING FOR In the near future,
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR In the near future,
# GOT EMBEDDING FOR In the Cenozoic era,
# GOT EMBEDDING FOR Late at night in a c
# GOT EMBEDDING FOR In Austin, Texas, Fa
# GOT EMBEDDING FOR Mike Milch (John Gal
# GOT EMBEDDING FOR A beautiful enchantr
# GOT EMBEDDING FOR Five young men pledg
# GOT EMBEDDING FOR In 1944, in the mids
# GOT EMBEDDING FOR A Manhattanite banke
# GOT EMBEDDING FOR The film opens showi
# GOT EMBEDDING FOR Eloise McGarry atten
# GOT EMBEDDING FOR Samantha Kingston wa
# GOT EMBEDDING FOR Mackenzie "Mack" Phi
# GOT EMBEDDING FOR In 2029, no mutants
# GOT EMBEDDING FOR Nursing assistant Ru
# GOT EMBEDDING FOR In the near future,
# GOT EMBEDDING FOR Casey, an American l
# GOT EMBEDDING FOR Bodi (Luke Wilson) i
# GOT EMBEDDING FOR African-American pho
# GOT EMBEDDING FOR In the year 1347 in
# GOT EMBEDDING FOR Mordred, an iron-fis
# GOT EMBEDDING FOR The movie starts wit
# GOT EMBEDDING FOR In "9 months B.C.",
# GOT EMBEDDING FOR Derek Cho, the film'
# GOT EMBEDDING FOR In the town of Ebbin
# GOT EMBEDDING FOR The story centers ar
# GOT EMBEDDING FOR After finally becomi
# GOT EMBEDDING FOR In 1934, famous Belg
# GOT EMBEDDING FOR Christine "Lady Bird
# GOT EMBEDDING FOR In 2003, Larry "Doc"
# GOT EMBEDDING FOR Amy (Mila Kunis) is
# GOT EMBEDDING FOR Two years after the
# GOT EMBEDDING FOR Teenager Belle Walke
# GOT EMBEDDING FOR The plot tells the s
# GOT EMBEDDING FOR This is a story of t
# GOT EMBEDDING FOR Criminal Edgar Munse
# GOT EMBEDDING FOR In 1959, the peacefu
# GOT EMBEDDING FOR After a harrowing 15
# GOT EMBEDDING FOR Steven Murphy, a ski
# GOT EMBEDDING FOR The film interlaces
# GOT EMBEDDING FOR At the Sawyer homest
# GOT EMBEDDING FOR After Ron Hall (Greg
# GOT EMBEDDING FOR The film opens after
# GOT EMBEDDING FOR Eric "Supe" Marsh, t
# GOT EMBEDDING FOR In 2019, following m
# GOT EMBEDDING FOR During a weekend exc
# GOT EMBEDDING FOR Thousands of years a
# GOT EMBEDDING FOR August "Auggie" Pull
# GOT EMBEDDING FOR The film begins duri
# GOT EMBEDDING FOR Emily Martin (Noël W
# GOT EMBEDDING FOR Molly Bloom is world
# GOT EMBEDDING FOR In 1973, 16-year-old
# GOT EMBEDDING FOR In 1892, settler Wes
# GOT EMBEDDING FOR The granddaughter of
# GOT EMBEDDING FOR In an alternate pres
# GOT EMBEDDING FOR In 1966 Vietnam, Sta
# GOT EMBEDDING FOR Kyle (Wilson) and Pe
# GOT EMBEDDING FOR In the future, searc
# GOT EMBEDDING FOR Three years after th
# GOT EMBEDDING FOR P. T. Barnum and his
# GOT EMBEDDING FOR In 1996 in Brantford
# GOT EMBEDDING FOR Mark Corley, a Los A
# GOT EMBEDDING FOR In Spain, a ranch ow
# GOT EMBEDDING FOR Shortly after the ba
# GOT EMBEDDING FOR Defense lawyer Duke,
# GOT EMBEDDING FOR In 1970s Portland, O
# GOT EMBEDDING FOR Mickey Rubin, a Cone
# GOT EMBEDDING FOR Elisa Esposito, who
# GOT EMBEDDING FOR A musician lives wit
# GOT EMBEDDING FOR Elio, a 17-year-old
# GOT EMBEDDING FOR In May 1940, the opp
# GOT EMBEDDING FOR In Santa Cecilia, Me
# GOT EMBEDDING FOR Roman J. Israel (Den
# GOT EMBEDDING FOR The story is told in
# GOT EMBEDDING FOR San Francisco, 1998:
# GOT EMBEDDING FOR Robin Cavendish fall
# GOT EMBEDDING FOR Frankie (Harris Dick
# GOT EMBEDDING FOR Patricia "Dumbo" Dom
# GOT EMBEDDING FOR Jimmy Logan is laid
# GOT EMBEDDING FOR Private UK-based bod
# GOT EMBEDDING FOR Thomas Webb (Callum
# GOT EMBEDDING FOR Ingrid Thorburn is a
# GOT EMBEDDING FOR Connie Nikas forcibl
# GOT EMBEDDING FOR Surly Squirrel is no
# GOT EMBEDDING FOR The unconventional,
# GOT EMBEDDING FOR In 1943, dollmaker S
# GOT EMBEDDING FOR A team of trained op
# GOT EMBEDDING FOR During a winter seas
# GOT EMBEDDING FOR Karla Dyson (Halle B
# GOT EMBEDDING FOR Eleven-year-old Jake
# GOT EMBEDDING FOR James lives in an un
# GOT EMBEDDING FOR On July 23, 1967, th
# GOT EMBEDDING FOR Gene is an emoji tha
# GOT EMBEDDING FOR Wall Street broker W
# GOT EMBEDDING FOR Four lifelong best f
# GOT EMBEDDING FOR In the 28th century,
# GOT EMBEDDING FOR Clare Shannon, a 17-
# GOT EMBEDDING FOR Two years have passe
# GOT EMBEDDING FOR Following the Battle
# GOT EMBEDDING FOR In 1940, Thurgood Ma
# GOT EMBEDDING FOR Based on a true stor
# GOT EMBEDDING FOR Menashe (Menashe Lus
# GOT EMBEDDING FOR Set in the Netherlan
# GOT EMBEDDING FOR The film dramatizes
# GOT EMBEDDING FOR Theresa "Tree" Gelbm
# GOT EMBEDDING FOR After an operation i
# GOT EMBEDDING FOR Former boxer and dru
# GOT EMBEDDING FOR Six-year-old Moonee
# GOT EMBEDDING FOR The ponies of Equest
# GOT EMBEDDING FOR In January, after th
# GOT EMBEDDING FOR A medical student, C
# GOT EMBEDDING FOR In the late 1970s, B
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Abdul Karim, a young
# GOT EMBEDDING FOR Theresa provides her
# GOT EMBEDDING FOR In 2049, replicants
# GOT EMBEDDING FOR Jeff Bauman is a wel
# GOT EMBEDDING FOR A young boy ventures
# GOT EMBEDDING FOR A year after the eve
# GOT EMBEDDING FOR Brad Sloan (Ben Stil
# GOT EMBEDDING FOR In a large house rec
# GOT EMBEDDING FOR On the morning of Se
# GOT EMBEDDING FOR Mitch Rapp and his g
# GOT EMBEDDING FOR In October 1988, Bil
# GOT EMBEDDING FOR Aging rock star Turk
# GOT EMBEDDING FOR Three Catholic pries
# GOT EMBEDDING FOR Davis is a successfu
# GOT EMBEDDING FOR Waking inside a labo
# GOT EMBEDDING FOR Mowgli is a "man cub
# GOT EMBEDDING FOR Will drives with his
# GOT EMBEDDING FOR Adapted from Sony Cl
# GOT EMBEDDING FOR To survive harsh eco
# GOT EMBEDDING FOR The story follows Mi
# GOT EMBEDDING FOR In Texas in the fall
# GOT EMBEDDING FOR Carl Black and his f
# GOT EMBEDDING FOR AP History teacher G
# GOT EMBEDDING FOR In a motel, Roy Toml
# GOT EMBEDDING FOR Toula Portokalos-Mil
# GOT EMBEDDING FOR Eighteen months afte
# GOT EMBEDDING FOR Former gymnastics Br
# GOT EMBEDDING FOR Pat, Sam, Reece and
# GOT EMBEDDING FOR When Spanish industr
# GOT EMBEDDING FOR Two years after the
# GOT EMBEDDING FOR Evil sorceress Queen
# GOT EMBEDDING FOR On Bird Island, an i
# GOT EMBEDDING FOR 26-year-old Louisa C
# GOT EMBEDDING FOR Set in Burleson, Tex
# GOT EMBEDDING FOR Two years after thei
# GOT EMBEDDING FOR Chapter One – Lookin
# GOT EMBEDDING FOR En Sabah Nur, a powe
# GOT EMBEDDING FOR In 1977 Los Angeles,
# GOT EMBEDDING FOR In the 1790s, the re
# GOT EMBEDDING FOR On the morning of De
# GOT EMBEDDING FOR Peter and Bronny Tay
# GOT EMBEDDING FOR Flamboyant televisio
# GOT EMBEDDING FOR In 1991, the brainwa
# GOT EMBEDDING FOR Above planet Tenemul
# GOT EMBEDDING FOR As Mother's Day draw
# GOT EMBEDDING FOR Smoke and Oil Dresde
# GOT EMBEDDING FOR After Evelyn forbids
# GOT EMBEDDING FOR Greta Evans, a young
# GOT EMBEDDING FOR Doris Miller is a sh
# GOT EMBEDDING FOR Jason Kelly is a law
# GOT EMBEDDING FOR Jane and her husband
# GOT EMBEDDING FOR Bernard "Bernie" Web
# GOT EMBEDDING FOR In the spirit realm,
# GOT EMBEDDING FOR Physicist Jim Beale,
# GOT EMBEDDING FOR In 1959, Ip Man is s
# GOT EMBEDDING FOR Ohio high-schooler C
# GOT EMBEDDING FOR Norm the polar bear
# GOT EMBEDDING FOR Charlie is a playboy
# GOT EMBEDDING FOR In 2012, Benghazi, L
# GOT EMBEDDING FOR The film starts in M
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Philosophy professor
# GOT EMBEDDING FOR The majority of the
# GOT EMBEDDING FOR In 1976, paranormal
# GOT EMBEDDING FOR In 1951, Eddie Manni
# GOT EMBEDDING FOR Early 19th century E
# GOT EMBEDDING FOR Travis Shaw (Benjami
# GOT EMBEDDING FOR Wade Wilson is a dis
# GOT EMBEDDING FOR At Fashion Interpol,
# GOT EMBEDDING FOR Alice (Dakota Johnso
# GOT EMBEDDING FOR After crushing a Zea
# GOT EMBEDDING FOR In 1630s New England
# GOT EMBEDDING FOR Jesse Owens, a promi
# GOT EMBEDDING FOR In an alternate vers
# GOT EMBEDDING FOR In Atlanta, Georgia,
# GOT EMBEDDING FOR In a world populated
# GOT EMBEDDING FOR Western intelligence
# GOT EMBEDDING FOR In 2003 New York Cit
# GOT EMBEDDING FOR Sets in the 19th cen
# GOT EMBEDDING FOR After breaking up wi
# GOT EMBEDDING FOR At the age of 7, whe
# GOT EMBEDDING FOR Told in the form of
# GOT EMBEDDING FOR Eighteen months afte
# GOT EMBEDDING FOR Draenor, the homewor
# GOT EMBEDDING FOR In 1879, robber baro
# GOT EMBEDDING FOR Set against the ante
# GOT EMBEDDING FOR Rachel Watson is an
# GOT EMBEDDING FOR In March 1997, Loomi
# GOT EMBEDDING FOR On April 20, 2010, D
# GOT EMBEDDING FOR For years, Abraham P
# GOT EMBEDDING FOR For generations, the
# GOT EMBEDDING FOR The film chronicles
# GOT EMBEDDING FOR Lee Weathers is a "r
# GOT EMBEDDING FOR In 2014, James Donah
# GOT EMBEDDING FOR In 2013, Edward Snow
# GOT EMBEDDING FOR On her 43rd birthday
# GOT EMBEDDING FOR Looking for a fresh
# GOT EMBEDDING FOR On a tiny isolated S
# GOT EMBEDDING FOR A married couple in
# GOT EMBEDDING FOR Rafe Khatchadorian (
# GOT EMBEDDING FOR As a child, Christia
# GOT EMBEDDING FOR In the film's spy su
# GOT EMBEDDING FOR Max Steel is an in-d
# GOT EMBEDDING FOR After dismantling a
# GOT EMBEDDING FOR Jeff Gaffney (Zach G
# GOT EMBEDDING FOR In 1967 Los Angeles,
# GOT EMBEDDING FOR Jonathan and his fra
# GOT EMBEDDING FOR In Littleton, Colora
# GOT EMBEDDING FOR In 1996, at the 45th
# GOT EMBEDDING FOR Harvard University p
# GOT EMBEDDING FOR Laura (Alycia Debnam
# GOT EMBEDDING FOR Research scientist G
# GOT EMBEDDING FOR Ray Kroc is a travel
# GOT EMBEDDING FOR In a world of anthro
# GOT EMBEDDING FOR Twelve-year-old Conn
# GOT EMBEDDING FOR On January 15, 2009,
# GOT EMBEDDING FOR On the Polynesian is
# GOT EMBEDDING FOR Tom Sherbourne, a tr
# GOT EMBEDDING FOR Three years into its
# GOT EMBEDDING FOR The film follows the
# GOT EMBEDDING FOR Dory, a regal blue t
# GOT EMBEDDING FOR In 1996, star athlet
# GOT EMBEDDING FOR Shortly after the de
# GOT EMBEDDING FOR After surviving the
# GOT EMBEDDING FOR Sixteen-year-old asp
# GOT EMBEDDING FOR As a result of the B
# GOT EMBEDDING FOR Sophie, a 10-year-ol
# GOT EMBEDDING FOR A young Charlie Roan
# GOT EMBEDDING FOR A Jack Russell Terri
# GOT EMBEDDING FOR Brothers Mike and Da
# GOT EMBEDDING FOR The story begins in
# GOT EMBEDDING FOR During the 1980s, U.
# GOT EMBEDDING FOR Physicists Abby Yate
# GOT EMBEDDING FOR Twenty years after t
# GOT EMBEDDING FOR Scrat, trying to bur
# GOT EMBEDDING FOR A supermarket called
# GOT EMBEDDING FOR In a textile factory
# GOT EMBEDDING FOR After faking his dea
# GOT EMBEDDING FOR Rocky, Alex, and Mon
# GOT EMBEDDING FOR In feudal Japan, 12-
# GOT EMBEDDING FOR A Jewish nobleman, J
# GOT EMBEDDING FOR Florence Foster Jenk
# GOT EMBEDDING FOR In 2005, David Packo
# GOT EMBEDDING FOR In 1977, Pete Healy,
# GOT EMBEDDING FOR A decade after he ex
# GOT EMBEDDING FOR Tom Brand (Kevin Spa
# GOT EMBEDDING FOR In the aftermath of
# GOT EMBEDDING FOR High school senior V
# GOT EMBEDDING FOR Amy Mitchell (Mila K
# GOT EMBEDDING FOR After losing her mot
# GOT EMBEDDING FOR After an argument wi
# GOT EMBEDDING FOR Muriel Donnelly and
# GOT EMBEDDING FOR Years after his movi
# GOT EMBEDDING FOR A skyrocketing crime
# GOT EMBEDDING FOR Medical researchers
# GOT EMBEDDING FOR In 1992, Dr Contrera
# GOT EMBEDDING FOR Agatha Weiss arrives
# GOT EMBEDDING FOR Five years after the
# GOT EMBEDDING FOR Seasoned con-man Nic
# GOT EMBEDDING FOR Everly (Salma Hayek)
# GOT EMBEDDING FOR Jim White, a footbal
# GOT EMBEDDING FOR In the Lower East Si
# GOT EMBEDDING FOR Cam (Taylor Lautner)
# GOT EMBEDDING FOR Don Champagne (Patri
# GOT EMBEDDING FOR A young girl named A
# GOT EMBEDDING FOR Haunted by his past,
# GOT EMBEDDING FOR Seeking a new start,
# GOT EMBEDDING FOR Five days after the
# GOT EMBEDDING FOR Jim Terrier (Sean Pe
# GOT EMBEDDING FOR A zombie outbreak is
# GOT EMBEDDING FOR James King is an ext
# GOT EMBEDDING FOR On the run from thei
# GOT EMBEDDING FOR In Depression-era No
# GOT EMBEDDING FOR Middle-aged couple J
# GOT EMBEDDING FOR Cathy sits alone wit
# GOT EMBEDDING FOR After defeating Owen
# GOT EMBEDDING FOR Bianca is enjoying h
# GOT EMBEDDING FOR Lord Charlie Mortdec
# GOT EMBEDDING FOR During a mission in
# GOT EMBEDDING FOR The story centers on
# GOT EMBEDDING FOR Programmer Caleb Smi
# GOT EMBEDDING FOR Forty years after th
# GOT EMBEDDING FOR Former covert operat
# GOT EMBEDDING FOR The film revolves ar
# GOT EMBEDDING FOR At a nuclear plant i
# GOT EMBEDDING FOR In a small American
# GOT EMBEDDING FOR In the deep jungles
# GOT EMBEDDING FOR Oscar Vazquez (Carlo
# GOT EMBEDDING FOR Jimmy Callahan (Kevi
# GOT EMBEDDING FOR A futuristic resort,
# GOT EMBEDDING FOR Although living what
# GOT EMBEDDING FOR Claire Peterson (Jen
# GOT EMBEDDING FOR Franny Ellis (Anne H
# GOT EMBEDDING FOR Twenty-one-year-old
# GOT EMBEDDING FOR A realm divided betw
# GOT EMBEDDING FOR Quinn (Simon Helberg
# GOT EMBEDDING FOR Elliot Anderson (Kev
# GOT EMBEDDING FOR Five married men sha
# GOT EMBEDDING FOR In 2014, 17-year-old
# GOT EMBEDDING FOR Nick Wild (Jason Sta
# GOT EMBEDDING FOR The drama follows th
# GOT EMBEDDING FOR Earth and countless
# GOT EMBEDDING FOR In a prologue, the w
# GOT EMBEDDING FOR A pirate named Burge
# GOT EMBEDDING FOR Jerry (Ryan Reynolds
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR In a series of flash
# GOT EMBEDDING FOR After narrowly escap
# GOT EMBEDDING FOR Luke Collins (Scott
# GOT EMBEDDING FOR Brothers Zach and Gr
# GOT EMBEDDING FOR Malcolm Adekanbi and
# GOT EMBEDDING FOR Riley Andersen is bo
# GOT EMBEDDING FOR Max, a Malinois[4] u
# GOT EMBEDDING FOR John Bennett has bee
# GOT EMBEDDING FOR Human Resistance lea
# GOT EMBEDDING FOR Minions are small, y
# GOT EMBEDDING FOR In 1989, scientist H
# GOT EMBEDDING FOR Gordon Townsend tell
# GOT EMBEDDING FOR At a video-game arca
# GOT EMBEDDING FOR In the Vatican, Vica
# GOT EMBEDDING FOR In an unnamed South-
# GOT EMBEDDING FOR 47 (Rupert Friend) i
# GOT EMBEDDING FOR In 1975, James "Whit
# GOT EMBEDDING FOR In May 1996 several
# GOT EMBEDDING FOR In 2035, the crew of
# GOT EMBEDDING FOR In Akron, Ohio, 24-y
# GOT EMBEDDING FOR In Buffalo, New York
# GOT EMBEDDING FOR When the Little Red-
# GOT EMBEDDING FOR In an alternate hist
# GOT EMBEDDING FOR In London, ambitious
# GOT EMBEDDING FOR In 2002, former Pitt
# GOT EMBEDDING FOR Mild-mannered radio
# GOT EMBEDDING FOR In 1990, Joy Mangano
# GOT EMBEDDING FOR Extreme sport athlet
# GOT EMBEDDING FOR In 1823, Hugh Glass
# GOT EMBEDDING FOR Single mother Billy
# GOT EMBEDDING FOR Awkward, lanky, and
# GOT EMBEDDING FOR In 1850, author Herm
# GOT EMBEDDING FOR The film alternates
# GOT EMBEDDING FOR In the Eastern Europ
# GOT EMBEDDING FOR Exactly 100 years af
# GOT EMBEDDING FOR Several years before
# GOT EMBEDDING FOR Ruthless tycoon and
# GOT EMBEDDING FOR In 1933, a child (Xa
# GOT EMBEDDING FOR Maya is a toque maca
# GOT EMBEDDING FOR After his mother's d
# GOT EMBEDDING FOR Christian Longo (Jam
# GOT EMBEDDING FOR The story is told th
# GOT EMBEDDING FOR After his company cr
# GOT EMBEDDING FOR The story of a gay t
# GOT EMBEDDING FOR In the seaside town
# GOT EMBEDDING FOR One afternoon in San
# GOT EMBEDDING FOR Paul Blart (Kevin Ja
# GOT EMBEDDING FOR In 1870 Victorian En
# GOT EMBEDDING FOR Eric and Amy Bowen a
# GOT EMBEDDING FOR Vincent Chase, who s
# GOT EMBEDDING FOR Raymond "Ray" Gaines
# GOT EMBEDDING FOR Anna Sasaki is an in
# GOT EMBEDDING FOR An adult Frank Walke
# GOT EMBEDDING FOR Military contractor
# GOT EMBEDDING FOR Three years after wi
# GOT EMBEDDING FOR Following a nuclear
# GOT EMBEDDING FOR In the present-day M
# GOT EMBEDDING FOR Rose Cooper is a San
# GOT EMBEDDING FOR Susan Cooper is a 40
# GOT EMBEDDING FOR Meghan Miles (Banks)
# GOT EMBEDDING FOR 11-year-old Annie Pa
# GOT EMBEDDING FOR Nate Norman (Jonatha
# GOT EMBEDDING FOR Rich is a sex addict
# GOT EMBEDDING FOR OsCorp scientist Ric
# GOT EMBEDDING FOR In Budapest, Hungary
# GOT EMBEDDING FOR Carly Whitten (Camer
# GOT EMBEDDING FOR In 2018, in a dystop
# GOT EMBEDDING FOR Elliot Brindle, a me
# GOT EMBEDDING FOR Dr. Will Caster (Joh
# GOT EMBEDDING FOR Spix's Macaws Blu an
# GOT EMBEDDING FOR Malcolm Johnson and
# GOT EMBEDDING FOR Four-year-old Colton
# GOT EMBEDDING FOR Four Asian school gi
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR The film takes place
# GOT EMBEDDING FOR On the morning of th
# GOT EMBEDDING FOR According to Dread C
# GOT EMBEDDING FOR In 2002, Ava, a 14-y
# GOT EMBEDDING FOR When a blue collar w
# GOT EMBEDDING FOR Two years after the
# GOT EMBEDDING FOR In 1993, in the work
# GOT EMBEDDING FOR Hazel Grace Lancaste
# GOT EMBEDDING FOR Allyson Field is a y
# GOT EMBEDDING FOR In 1985, 13-year-old
# GOT EMBEDDING FOR When Joel (Rudd) and
# GOT EMBEDDING FOR As a young boy, Noah
# GOT EMBEDDING FOR Cedric (Kevin Hart)
# GOT EMBEDDING FOR In Belleville, New J
# GOT EMBEDDING FOR Three MIT students –
# GOT EMBEDDING FOR After performing a s
# GOT EMBEDDING FOR Five years after the
# GOT EMBEDDING FOR Thirteen-year-old Ja
# GOT EMBEDDING FOR Two years following
# GOT EMBEDDING FOR In 2015, an alien ra
# GOT EMBEDDING FOR Mac (Seth Rogen) and
# GOT EMBEDDING FOR In 1882, in the town
# GOT EMBEDDING FOR Maleficent is a powe
# GOT EMBEDDING FOR In a dystopian futur
# GOT EMBEDDING FOR Ann Dane, startled b
# GOT EMBEDDING FOR Divorcee Lauren Reyn
# GOT EMBEDDING FOR Henry Altmann (Robin
# GOT EMBEDDING FOR J. B. Bernstein is a
# GOT EMBEDDING FOR In 1954, Godzilla, a
# GOT EMBEDDING FOR In 2004, Broadway di
# GOT EMBEDDING FOR John "Breacher" Whar
# GOT EMBEDDING FOR An investigation of
# GOT EMBEDDING FOR A misfit group of Ne
# GOT EMBEDDING FOR Every ten years for
# GOT EMBEDDING FOR Mr. Zimit, a philoso
# GOT EMBEDDING FOR Kevin (Billy Zane) a
# GOT EMBEDDING FOR In 1943, the Allies
# GOT EMBEDDING FOR In the year 2098, Lo
# GOT EMBEDDING FOR In Wilmington, Delaw
# GOT EMBEDDING FOR Jason (Zac Efron) is
# GOT EMBEDDING FOR In 1987, Adele Wheel
# GOT EMBEDDING FOR A tugboat pulling a
# GOT EMBEDDING FOR In 1795, Dr. Victor
# GOT EMBEDDING FOR James Payton is a de
# GOT EMBEDDING FOR Laurel and Audrey (Z
# GOT EMBEDDING FOR In the fictional tow
# GOT EMBEDDING FOR James Burns is in pr
# GOT EMBEDDING FOR After the terrorist
# GOT EMBEDDING FOR A young couple, Zach
# GOT EMBEDDING FOR In 1200 BC ancient G
# GOT EMBEDDING FOR Chloe, a single moth
# GOT EMBEDDING FOR A man (Sharlto Cople
# GOT EMBEDDING FOR In June 2012, high s
# GOT EMBEDDING FOR The film opens in a
# GOT EMBEDDING FOR Abby Russell is a se
# GOT EMBEDDING FOR The story features 1
# GOT EMBEDDING FOR Following the events
# GOT EMBEDDING FOR Years after a drunke
# GOT EMBEDDING FOR Josh Wheaton (Shane
# GOT EMBEDDING FOR In a futuristic dyst
# GOT EMBEDDING FOR Craig (Pat Healy) is
# GOT EMBEDDING FOR Nine years after the
# GOT EMBEDDING FOR Tobey Marshall is a
# GOT EMBEDDING FOR Doug Varney (Sam Roc
# GOT EMBEDDING FOR Mr. Peabody is a gif
# GOT EMBEDDING FOR Queen Gorgo of Spart
# GOT EMBEDDING FOR John, the last survi
# GOT EMBEDDING FOR Alcoholic U.S. Air M
# GOT EMBEDDING FOR Recent college gradu
# GOT EMBEDDING FOR Brutal gangster Drag
# GOT EMBEDDING FOR After her sister Liz
# GOT EMBEDDING FOR Jay Wheeler, the "bl
# GOT EMBEDDING FOR The film centers aro
# GOT EMBEDDING FOR Experienced CIA agen
# GOT EMBEDDING FOR When a Former Specia
# GOT EMBEDDING FOR In 2028, multination
# GOT EMBEDDING FOR Beautiful-but-shy At
# GOT EMBEDDING FOR Elise Miller (Grace
# GOT EMBEDDING FOR Sixty-five million y
# GOT EMBEDDING FOR Aidan Bloom (Zach Br
# GOT EMBEDDING FOR Three neighborhood t
# GOT EMBEDDING FOR Kate (Hilary Swank)
# GOT EMBEDDING FOR Debbie Galardi recal
# GOT EMBEDDING FOR Megan (Keira Knightl
# GOT EMBEDDING FOR In a post-drought ap
# GOT EMBEDDING FOR Petty thief Louis "L
# GOT EMBEDDING FOR Philip (Jason Schwar
# GOT EMBEDDING FOR In April 1945, the A
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Mary Beth, a museum
# GOT EMBEDDING FOR Riggan Thomson is a
# GOT EMBEDDING FOR Andrew Neiman is a f
# GOT EMBEDDING FOR Boyd Mitchler and hi
# GOT EMBEDDING FOR Hank Palmer (Robert
# GOT EMBEDDING FOR Before the Renaissan
# GOT EMBEDDING FOR The film follows the
# GOT EMBEDDING FOR On the outside Zoe R
# GOT EMBEDDING FOR Jessica Loren, a roo
# GOT EMBEDDING FOR University of Centra
# GOT EMBEDDING FOR During the Second Su
# GOT EMBEDDING FOR The day of their fif
# GOT EMBEDDING FOR In 1967 in Santa Mon
# GOT EMBEDDING FOR In the mid-21st cent
# GOT EMBEDDING FOR Hiro Hamada is a 14-
# GOT EMBEDDING FOR Robert McCall (Denze
# GOT EMBEDDING FOR In 1300 BC, Moses, a
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR A Baker (James Corde
# GOT EMBEDDING FOR Dave Skylark is the
# GOT EMBEDDING FOR In 1958, Margaret Ul
# GOT EMBEDDING FOR In 1938 Egypt, a tea
# GOT EMBEDDING FOR In Harlem, Manhattan
# GOT EMBEDDING FOR New York Times repor
# GOT EMBEDDING FOR The different parts
# GOT EMBEDDING FOR In June 1995, despit
# GOT EMBEDDING FOR The recently widowed
# GOT EMBEDDING FOR In Antarctica, three
# GOT EMBEDDING FOR In November 2014, Ni
# GOT EMBEDDING FOR After being rescued
# GOT EMBEDDING FOR In a framing sequenc
# GOT EMBEDDING FOR Mary Bee Cuddy (Hila
# GOT EMBEDDING FOR Olympic wrestling ch
# GOT EMBEDDING FOR Twenty years after t
# GOT EMBEDDING FOR Noni Jean is a hot n
# GOT EMBEDDING FOR The pregnant Jessabe
# GOT EMBEDDING FOR In 1962, con man Che
# GOT EMBEDDING FOR In 1970, Shasta Fay
# GOT EMBEDDING FOR In the fictional hil
# GOT EMBEDDING FOR Oren Little (Douglas
# GOT EMBEDDING FOR Six months after the
# GOT EMBEDDING FOR A tornado hits the c
# GOT EMBEDDING FOR The Kadam family ran
# GOT EMBEDDING FOR A teen track runner
# GOT EMBEDDING FOR During a visit to Ka
# GOT EMBEDDING FOR In 1988, following h
# GOT EMBEDDING FOR Get on Up is told us
# GOT EMBEDDING FOR In 1928, a globally
# GOT EMBEDDING FOR Hercules is the lead
# GOT EMBEDDING FOR Jay and Annie Hargro
# GOT EMBEDDING FOR Two longtime friends
# GOT EMBEDDING FOR On March 21, 2023, t
# GOT EMBEDDING FOR Since winning the Wi
# GOT EMBEDDING FOR Reformed drug addict
# GOT EMBEDDING FOR A Ph.D. student, Ian
# GOT EMBEDDING FOR After murdering his
# GOT EMBEDDING FOR Paul Maguire and his
# GOT EMBEDDING FOR Ten years after the
# GOT EMBEDDING FOR In 2002, six-year-ol
# GOT EMBEDDING FOR Best friends Wallace
# GOT EMBEDDING FOR April O'Neil, a loca
# GOT EMBEDDING FOR In Murphysboro, Illi
# GOT EMBEDDING FOR The Expendables—led
# GOT EMBEDDING FOR The owner of the 20t
# GOT EMBEDDING FOR Judd Altman (Jason B
# GOT EMBEDDING FOR Following a calamity
# GOT EMBEDDING FOR Milo (Hader) writes
# GOT EMBEDDING FOR Suki, a young woman
# GOT EMBEDDING FOR In 1991, Detective M
# GOT EMBEDDING FOR Spencer and Laura Pe
# GOT EMBEDDING FOR In Tennessee, a pris
# GOT EMBEDDING FOR Bea (Rose Leslie) an
# GOT EMBEDDING FOR Three years after sa
# GOT EMBEDDING FOR A teenager wakes up
# GOT EMBEDDING FOR A young couple, Cath
# GOT EMBEDDING FOR Paul, a mechanic, sp
# GOT EMBEDDING FOR Mia Hall and her fam
# GOT EMBEDDING FOR After his girlfriend
# GOT EMBEDDING FOR Ben and George, a sa
# GOT EMBEDDING FOR Confronted with the
# GOT EMBEDDING FOR Marv regains conscio
# GOT EMBEDDING FOR Scarlett Marlowe, a
# GOT EMBEDDING FOR Professor Jonathan V
# GOT EMBEDDING FOR Emily (Olesya Rulin)
# GOT EMBEDDING FOR The story, about los
# GOT EMBEDDING FOR Following their succ
# GOT EMBEDDING FOR The story opens in 2
# GOT EMBEDDING FOR Chip, a young dancer
# GOT EMBEDDING FOR Frances Halladay is
# GOT EMBEDDING FOR Generation Iron chro
# GOT EMBEDDING FOR The film opens in an
# GOT EMBEDDING FOR Reggie the turkey ha
# GOT EMBEDDING FOR Charley Brewster, Ed
# GOT EMBEDDING FOR Princess Elsa of Are
# GOT EMBEDDING FOR In 1949 Los Angeles,
# GOT EMBEDDING FOR The film depicts the
# GOT EMBEDDING FOR Tanner Daniels (Mich
# GOT EMBEDDING FOR Following the events
# GOT EMBEDDING FOR In the woods, severa
# GOT EMBEDDING FOR Nikki (Bening) is a
# GOT EMBEDDING FOR Brigadier-General Bo
# GOT EMBEDDING FOR Dr. Unger (Embeth Da
# GOT EMBEDDING FOR Kate (Olivia Wilde)
# GOT EMBEDDING FOR The Barrett family—m
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Victor (Colin Farrel
# GOT EMBEDDING FOR A mysterious vehicle
# GOT EMBEDDING FOR An ambitious, up-and
# GOT EMBEDDING FOR Jon Martello is a yo
# GOT EMBEDDING FOR Dracula, a Romanian
# GOT EMBEDDING FOR In 2154, Earth is ov
# GOT EMBEDDING FOR Ray Breslin is a for
# GOT EMBEDDING FOR Washed up former rac
# GOT EMBEDDING FOR After failing to get
# GOT EMBEDDING FOR In the future, human
# GOT EMBEDDING FOR Eva, a masseuse and
# GOT EMBEDDING FOR 17 year old Mary Kat
# GOT EMBEDDING FOR Ben Logan is an Amer
# GOT EMBEDDING FOR Scorch Supernova (Br
# GOT EMBEDDING FOR Sixteen-year-old Rus
# GOT EMBEDDING FOR Three years after th
# GOT EMBEDDING FOR Imogene Duncan (Kris
# GOT EMBEDDING FOR After the 74th Hunge
# GOT EMBEDDING FOR Thorin and his compa
# GOT EMBEDDING FOR Pro baseball player
# GOT EMBEDDING FOR Two years after the
# GOT EMBEDDING FOR College student Beth
# GOT EMBEDDING FOR The human race has b
# GOT EMBEDDING FOR In 2005, before Hurr
# GOT EMBEDDING FOR 1951 - Having alread
# GOT EMBEDDING FOR Wealthy drug dealer
# GOT EMBEDDING FOR In the 1970s, succes
# GOT EMBEDDING FOR Missouri-born Katie
# GOT EMBEDDING FOR In the 1960s, Richar
# GOT EMBEDDING FOR In Denver, accountan
# GOT EMBEDDING FOR Sam Sotto is a Holly
# GOT EMBEDDING FOR The framing device h
# GOT EMBEDDING FOR A cave family called
# GOT EMBEDDING FOR In 1982, young Alber
# GOT EMBEDDING FOR In a near future Los
# GOT EMBEDDING FOR FBI agent Sarah Ashb
# GOT EMBEDDING FOR When once-up-and-com
# GOT EMBEDDING FOR The film is set in 1
# GOT EMBEDDING FOR Bernice (Lisa Gay Ha
# GOT EMBEDDING FOR In Moscow, Viktor Ch
# GOT EMBEDDING FOR Grace "Gracie" Trey
# GOT EMBEDDING FOR NASA Space Shuttle E
# GOT EMBEDDING FOR In 1931, Nick Carraw
# GOT EMBEDDING FOR Justine, a college f
# GOT EMBEDDING FOR In 1991, a young Jef
# GOT EMBEDDING FOR In their prime, Pitt
# GOT EMBEDDING FOR Two years after the
# GOT EMBEDDING FOR Teen siblings Hansel
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Abandoned by their f
# GOT EMBEDDING FOR The film picks up im
# GOT EMBEDDING FOR Johanna Parry (Krist
# GOT EMBEDDING FOR In August 2012, a yo
# GOT EMBEDDING FOR In July 1985, Dallas
# GOT EMBEDDING FOR Nine years have pass
# GOT EMBEDDING FOR A high-level cartel
# GOT EMBEDDING FOR Pathologically singl
# GOT EMBEDDING FOR Following a family d
# GOT EMBEDDING FOR A group of refugees
# GOT EMBEDDING FOR In the competitive w
# GOT EMBEDDING FOR Former pro golfer Wa
# GOT EMBEDDING FOR Loveable losers Kate
# GOT EMBEDDING FOR In the midst of the
# GOT EMBEDDING FOR The title designates
# GOT EMBEDDING FOR Dante Graham enlists
# GOT EMBEDDING FOR In 1980, Ron Burgund
# GOT EMBEDDING FOR In Alabama, Oodie br
# GOT EMBEDDING FOR In Gatlin, South Car
# GOT EMBEDDING FOR In the wake of the 2
# GOT EMBEDDING FOR In 1977, 18-year-old
# GOT EMBEDDING FOR Six high school seni
# GOT EMBEDDING FOR In the wake of his p
# GOT EMBEDDING FOR Minnesotans Scott (J
# GOT EMBEDDING FOR The film stars Harry
# GOT EMBEDDING FOR In 1978, con artists
# GOT EMBEDDING FOR The film starts with
# GOT EMBEDDING FOR In late medieval Jap
# GOT EMBEDDING FOR Criminals Robert "Bo
# GOT EMBEDDING FOR Paramedic Nick Mallo
# GOT EMBEDDING FOR In 1841, Solomon Nor
# GOT EMBEDDING FOR Friends since high s
# GOT EMBEDDING FOR Follow actor J Kimba
# GOT EMBEDDING FOR After living in a ps
# GOT EMBEDDING FOR In 1945, after sport
# GOT EMBEDDING FOR Frankie is a hard-dr
# GOT EMBEDDING FOR In the Indian Ocean,
# GOT EMBEDDING FOR The film is divided
# GOT EMBEDDING FOR Five friends explore
# GOT EMBEDDING FOR A content and succes
# GOT EMBEDDING FOR Straight-laced Princ
# GOT EMBEDDING FOR In the near future,
# GOT EMBEDDING FOR Three travelers, Gri
# GOT EMBEDDING FOR Ruth Guthrie is walk
# GOT EMBEDDING FOR Mia Sullivan (Monica
# GOT EMBEDDING FOR Alex Mathis (Greg Gr
# GOT EMBEDDING FOR Jack Kerouac, coming
# GOT EMBEDDING FOR Inventor Flint Lockw
# GOT EMBEDDING FOR Richard Phillips tak
# GOT EMBEDDING FOR Alone in her home, M
# GOT EMBEDDING FOR In 1970s New York Ci
# GOT EMBEDDING FOR Charlie Countryman,
# GOT EMBEDDING FOR The movie opens with
# GOT EMBEDDING FOR The story begins wit
# GOT EMBEDDING FOR "The Cloth" of the t
# GOT EMBEDDING FOR In Hollywood, Samant
# GOT EMBEDDING FOR Don and Ellie Griffi
# GOT EMBEDDING FOR The single-player ca
# GOT EMBEDDING FOR A recently widowed s
# GOT EMBEDDING FOR In 1980, an annual g
# GOT EMBEDDING FOR Abby Ableman is a le
# GOT EMBEDDING FOR In 1971, Roger and C
# GOT EMBEDDING FOR A bullied teen chef
# GOT EMBEDDING FOR In a morgue, BJ has
# GOT EMBEDDING FOR When Christian, an L
# GOT EMBEDDING FOR Dan Mulligan (Mark R
# GOT EMBEDDING FOR Los Angeles Police D
# GOT EMBEDDING FOR David (Jonathan Grof
# GOT EMBEDDING FOR After his mother, Na
# GOT EMBEDDING FOR Sarah (Kate Bosworth
# GOT EMBEDDING FOR A drama set in New M
# GOT EMBEDDING FOR Quiet teenager Marc
# GOT EMBEDDING FOR The movie opens with
# GOT EMBEDDING FOR Jasmine Francis (Cat
# GOT EMBEDDING FOR Dwight Evans, living
# GOT EMBEDDING FOR In Shushan, the capi
# GOT EMBEDDING FOR In February 1938, a
# GOT EMBEDDING FOR Two of the highest r
# GOT EMBEDDING FOR Keith Reynolds is a
# GOT EMBEDDING FOR Bridegroom chronicle
# GOT EMBEDDING FOR NYPD detective Billy
# GOT EMBEDDING FOR In the city of New O
# GOT EMBEDDING FOR In 2009, an elderly
# GOT EMBEDDING FOR Blynn Lehman, one of
# GOT EMBEDDING FOR An expectant couple
# GOT EMBEDDING FOR During a sweltering
# GOT EMBEDDING FOR After her husband Ma
# GOT EMBEDDING FOR Season of Miracles c
# GOT EMBEDDING FOR  Walter Mitty is a n
# GOT EMBEDDING FOR Salesman Zach Newman
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Sam (Josh Gad) is a
# GOT EMBEDDING FOR Grace is the young s
# GOT EMBEDDING FOR While drunk, Robert
# GOT EMBEDDING FOR John Moon's wife rec
# GOT EMBEDDING FOR Charlie Sheen and Li
# GOT EMBEDDING FOR In preparation for h
# GOT EMBEDDING FOR As the story begins,
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Set entirely inside
# GOT EMBEDDING FOR Sutter Keely (Miles
# GOT EMBEDDING FOR Debris from a destro
# GOT EMBEDDING FOR College students Bri
# GOT EMBEDDING FOR Mitchell and Carter,
# GOT EMBEDDING FOR In 1961, the financi
# GOT EMBEDDING FOR Neil, a seemingly no
# GOT EMBEDDING FOR Set during a single
# GOT EMBEDDING FOR In 1988, an odd pair
# GOT EMBEDDING FOR In suburban Pennsylv
# GOT EMBEDDING FOR While walking home f
# GOT EMBEDDING FOR In 2014, the New Fou
# GOT EMBEDDING FOR Lindsey Lewis and he
# GOT EMBEDDING FOR 75-year-old Dr. Nath
# GOT EMBEDDING FOR Three years after th
# GOT EMBEDDING FOR Five years after Kyr
# GOT EMBEDDING FOR Director Salvador Li
# GOT EMBEDDING FOR Boston Police Depart
# GOT EMBEDDING FOR At Kinetech Labs, an
# GOT EMBEDDING FOR In the year 2044, a
# GOT EMBEDDING FOR Richie Furst used to
# GOT EMBEDDING FOR A terrified woman, K
# GOT EMBEDDING FOR The film starts with
# GOT EMBEDDING FOR Narrated by a 95-yea
# GOT EMBEDDING FOR Two children, Howie
# GOT EMBEDDING FOR Released from prison
# GOT EMBEDDING FOR In 2259, Captain Jam
# GOT EMBEDDING FOR Suzanne is a success
# GOT EMBEDDING FOR A paleontologist nam
# GOT EMBEDDING FOR About eight years af
# GOT EMBEDDING FOR Fourteen-year-old Du
# GOT EMBEDDING FOR In February 1961, Ll
# GOT EMBEDDING FOR A small-time cannabi
# GOT EMBEDDING FOR An office team go on
# GOT EMBEDDING FOR President of the Uni
# GOT EMBEDDING FOR There is a local myt
# GOT EMBEDDING FOR Kantmiss Evershot pr
# GOT EMBEDDING FOR In 1987, Jordan Belf
# GOT EMBEDDING FOR In 1945, Logan is he
# GOT EMBEDDING FOR Former UN employee G
# GOT EMBEDDING FOR Eric Harson and his
# GOT EMBEDDING FOR Steve Dallas (Owen W
# GOT EMBEDDING FOR Scott Weidemeyer (Sa
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR An enigmatic phone c
# GOT EMBEDDING FOR Violet (Alexis Blede
# GOT EMBEDDING FOR The film takes place
# GOT EMBEDDING FOR The film is presente
# GOT EMBEDDING FOR On her 18th birthday
# GOT EMBEDDING FOR Scott (Ryan Phillipp
# GOT EMBEDDING FOR High school senior C
# GOT EMBEDDING FOR In a farm in Fernfie
# GOT EMBEDDING FOR Offering herself as
# GOT EMBEDDING FOR In the late 1800s, a
# GOT EMBEDDING FOR The film starts with
# GOT EMBEDDING FOR The film starts in a
# GOT EMBEDDING FOR Following the events
# GOT EMBEDDING FOR Jay Baruchel arrives
# GOT EMBEDDING FOR Eons ago, Bor, fathe
# GOT EMBEDDING FOR In a suburban San Fe
# GOT EMBEDDING FOR The Peeples is an af
# GOT EMBEDDING FOR A 17-year-old Brookl
# GOT EMBEDDING FOR The film starts with
# GOT EMBEDDING FOR During a torrential
# GOT EMBEDDING FOR While on the phone w
# GOT EMBEDDING FOR Billy, Paddy, Archie
# GOT EMBEDDING FOR Joe Toy (Nick Robins
# GOT EMBEDDING FOR Paolo, a screenwrite
# GOT EMBEDDING FOR First-time filmmaker
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Two underachieving c
# GOT EMBEDDING FOR A couple, Jared (Jud
# GOT EMBEDDING FOR Sheriff Ray Owens is
# GOT EMBEDDING FOR Jimi Lazer, front-ma
# GOT EMBEDDING FOR As a young man in th
# GOT EMBEDDING FOR This psychological t
# GOT EMBEDDING FOR In Detroit in 1978,
# GOT EMBEDDING FOR Leigh London is a ta
# GOT EMBEDDING FOR In 1933, a boy named
# GOT EMBEDDING FOR In Salem, Massachuse
# GOT EMBEDDING FOR The movie begins as
# GOT EMBEDDING FOR In 1970, 20-year-old
# GOT EMBEDDING FOR During the Bosnian W
# GOT EMBEDDING FOR Dave Lizewski, bored
# GOT EMBEDDING FOR Ellie Klug is a musi
# GOT EMBEDDING FOR A suicide bomber det
# GOT EMBEDDING FOR After losing her ban
# GOT EMBEDDING FOR In 1986, Lorraine La
# GOT EMBEDDING FOR Salesmen Billy McMah
# GOT EMBEDDING FOR At a New Year's Eve
# GOT EMBEDDING FOR Four couples gather
# GOT EMBEDDING FOR After climbing a gia
# GOT EMBEDDING FOR In the Kingdom of Cl
# GOT EMBEDDING FOR After winning $10,00
# GOT EMBEDDING FOR Kevin is throwing a
# GOT EMBEDDING FOR The film is set in 1
# GOT EMBEDDING FOR The film opens in 20
# GOT EMBEDDING FOR David Wong, a slacke
# GOT EMBEDDING FOR Joe Ransom is a fore
# GOT EMBEDDING FOR A backwoods communit
# GOT EMBEDDING FOR While visiting his m
# GOT EMBEDDING FOR The sequel to Never
# GOT EMBEDDING FOR In Afghanistan, Tali
# GOT EMBEDDING FOR Billy is sitting in
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Parker (Jason Statha
# GOT EMBEDDING FOR In 1905 Kansas, Osca
# GOT EMBEDDING FOR In 2013, huge alien
# GOT EMBEDDING FOR The film follows Tom
# GOT EMBEDDING FOR In 1995, schemer Dan
# GOT EMBEDDING FOR Lamb Mannerhelm (Jul
# GOT EMBEDDING FOR Adam Cassidy is a lo
# GOT EMBEDDING FOR With all the picture
# GOT EMBEDDING FOR Parkland weaves toge
# GOT EMBEDDING FOR Former Army Ranger M
# GOT EMBEDDING FOR An old gangster, wit
# GOT EMBEDDING FOR Sara Taylor is a pho
# GOT EMBEDDING FOR While in Camp Half-B
# GOT EMBEDDING FOR London based journal
# GOT EMBEDDING FOR In 1997, Luke Glanto
# GOT EMBEDDING FOR Machete Cortez (Dann
# GOT EMBEDDING FOR Dusty Crophopper is
# GOT EMBEDDING FOR After getting off wo
# GOT EMBEDDING FOR Captain Dmitri "Demi
# GOT EMBEDDING FOR In 1993, alcoholic a
# GOT EMBEDDING FOR New York City teenag
# GOT EMBEDDING FOR While investigating
# GOT EMBEDDING FOR In Atlanta, Georgia
# GOT EMBEDDING FOR With Krypton destabi
# GOT EMBEDDING FOR When a businessman's
# GOT EMBEDDING FOR Amid aerial footage
# GOT EMBEDDING FOR Michael "Mike" Wazow
# GOT EMBEDDING FOR Jake Carter (The Miz
# GOT EMBEDDING FOR Movie 43 is a series
# GOT EMBEDDING FOR While traveling cros
# GOT EMBEDDING FOR In 2077, sixty years
# GOT EMBEDDING FOR Four stage magicians
# GOT EMBEDDING FOR Alicia (Juno Temple)
# GOT EMBEDDING FOR The plot of the film
# GOT EMBEDDING FOR In Billings, Montana
# GOT EMBEDDING FOR Two 14-year-old boys
# GOT EMBEDDING FOR It is 2006, and 19-y
# GOT EMBEDDING FOR Sandra, manager of a
# GOT EMBEDDING FOR Chris Farraday (Mark
# GOT EMBEDDING FOR 12-year old Ida Clay
# GOT EMBEDDING FOR Zack (Haas) is a you
# GOT EMBEDDING FOR A mixed-blood Native
# GOT EMBEDDING FOR Eight years after th
# GOT EMBEDDING FOR Newly transferred co
# GOT EMBEDDING FOR Swanson (Tim Heideck
# GOT EMBEDDING FOR In 1760, the Collins
# GOT EMBEDDING FOR Casper Galloway, an
# GOT EMBEDDING FOR Beth Winter (Keaton)
# GOT EMBEDDING FOR Kate is a shark expe
# GOT EMBEDDING FOR In February 2012, Se
# GOT EMBEDDING FOR Arkansas, November 1
# GOT EMBEDDING FOR Teenager Elena Peter
# GOT EMBEDDING FOR Will Shaw (Henry Cav
# GOT EMBEDDING FOR In the Chatham Islan
# GOT EMBEDDING FOR The film is about a
# GOT EMBEDDING FOR The Citizen integrat
# GOT EMBEDDING FOR Strange electrical c
# GOT EMBEDDING FOR The film takes place
# GOT EMBEDDING FOR Oscar is the nicknam
# GOT EMBEDDING FOR Chris (Jesse McCartn
# GOT EMBEDDING FOR In 1987, an 8-year-o
# GOT EMBEDDING FOR Darrell, played by a
# GOT EMBEDDING FOR Celeste (Rashida Jon
# GOT EMBEDDING FOR Young newsparer repo
# GOT EMBEDDING FOR Armando Álvarez (Wil
# GOT EMBEDDING FOR After a casino heist
# GOT EMBEDDING FOR For their vacation,
# GOT EMBEDDING FOR Death Race owner R.H
# GOT EMBEDDING FOR Detachment is a chro
# GOT EMBEDDING FOR Democratic Congressm
# GOT EMBEDDING FOR Joby Taylor (Paul Da
# GOT EMBEDDING FOR After Lauren is dump
# GOT EMBEDDING FOR Airline pilot Captai
# GOT EMBEDDING FOR Toby (Clint Black) c
# GOT EMBEDDING FOR Tom Solomon (Jason S
# GOT EMBEDDING FOR The seven adult sibl
# GOT EMBEDDING FOR Dave, a senior in hi
# GOT EMBEDDING FOR Following a grueling
# GOT EMBEDDING FOR Two clownfish, Marli
# GOT EMBEDDING FOR Tom, a scientist, in
# GOT EMBEDDING FOR The Expendables—lead
# GOT EMBEDDING FOR James (Jameel Saleem
# GOT EMBEDDING FOR Pauline is a disturb
# GOT EMBEDDING FOR Brian Taylor and Mig
# GOT EMBEDDING FOR When the mother of h
# GOT EMBEDDING FOR When Santa leaves an
# GOT EMBEDDING FOR Nine people board an
# GOT EMBEDDING FOR Hyun Jae, or Jae for
# GOT EMBEDDING FOR Zack (Chris Salvator
# GOT EMBEDDING FOR The unexpected death
# GOT EMBEDDING FOR St. Jude Square is a
# GOT EMBEDDING FOR In Los Angeles, Cali
# GOT EMBEDDING FOR The film is about tw
# GOT EMBEDDING FOR In 1858 Texas, the S
# GOT EMBEDDING FOR For years, the ficti
# GOT EMBEDDING FOR The Heffley family a
# GOT EMBEDDING FOR On October 30, 1989,
# GOT EMBEDDING FOR High school student
# GOT EMBEDDING FOR The film’s opening c
# GOT EMBEDDING FOR On November 4, 1979,
# GOT EMBEDDING FOR Robert Carlyle plays
# GOT EMBEDDING FOR Frank Vega (Danny Tr
# GOT EMBEDDING FOR The Asgardian Loki e
# GOT EMBEDDING FOR David Hargrove (Bria
# GOT EMBEDDING FOR Dagny Taggart pilots
# GOT EMBEDDING FOR Twelve-year-old Gret
# GOT EMBEDDING FOR Sixty-year-old magna
# GOT EMBEDDING FOR On May 21, 1973, six
# GOT EMBEDDING FOR Rudy Donatello (Alan
# GOT EMBEDDING FOR Thirteen years after
# GOT EMBEDDING FOR A young Peter Parker
# GOT EMBEDDING FOR As a zombie apocalyp
# GOT EMBEDDING FOR The plot follows the
# GOT EMBEDDING FOR In October 2004, a N
# GOT EMBEDDING FOR In 2011, a group of
# GOT EMBEDDING FOR Dr. Alex Cross (Tyle
# GOT EMBEDDING FOR After a major electr
# GOT EMBEDDING FOR When mob boss Bellav
# GOT EMBEDDING FOR In 2012, Ana, a fail
# GOT EMBEDDING FOR In the Philippines,
# GOT EMBEDDING FOR In 1818, Abraham Lin
# GOT EMBEDDING FOR After his mother Nan
# GOT EMBEDDING FOR Angelina (Hinshaw) i
# GOT EMBEDDING FOR When a massive tecto
# GOT EMBEDDING FOR Two brothers (Charli
# GOT EMBEDDING FOR A novelist and a cor
# GOT EMBEDDING FOR In 2005, scholarly s
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Joshua Mason (Josh H
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR A SWAT team barges i
# GOT EMBEDDING FOR In a high tech under
# GOT EMBEDDING FOR A year after the eve
# GOT EMBEDDING FOR The film takes place
# GOT EMBEDDING FOR A teens life is shat
# GOT EMBEDDING FOR One night, a young m
# GOT EMBEDDING FOR In Medieval Scotland
# GOT EMBEDDING FOR In early 1980s Sovie
# GOT EMBEDDING FOR Jeremy Reins, a U.S.
# GOT EMBEDDING FOR Six weeks after Jaso
# GOT EMBEDDING FOR Stone portrays journ
# GOT EMBEDDING FOR On a normal day at a
# GOT EMBEDDING FOR Scooby-Doo and the g
# GOT EMBEDDING FOR In small town Alaska
# GOT EMBEDDING FOR A detective searchin
# GOT EMBEDDING FOR After their wedding
# GOT EMBEDDING FOR In small-town Cartha
# GOT EMBEDDING FOR Detective Nick Blade
# GOT EMBEDDING FOR Ben Banks, the 28-ye
# GOT EMBEDDING FOR Nick Flynn (Dano) is
# GOT EMBEDDING FOR Every day Alex wakes
# GOT EMBEDDING FOR One winter's night,
# GOT EMBEDDING FOR As a storm approache
# GOT EMBEDDING FOR Following the legali
# GOT EMBEDDING FOR The movie explains t
# GOT EMBEDDING FOR In 2005, the Gliese
# GOT EMBEDDING FOR After a zombie apoca
# GOT EMBEDDING FOR Barricade tells the
# GOT EMBEDDING FOR Two young campers wa
# GOT EMBEDDING FOR During summertime, M
# GOT EMBEDDING FOR In Tel Aviv, 1973, y
# GOT EMBEDDING FOR Marley Corbett is a
# GOT EMBEDDING FOR The B-17F Lucky Lass
# GOT EMBEDDING FOR A year after the mas
# GOT EMBEDDING FOR While admiring a ros
# GOT EMBEDDING FOR Kate Hannah (Mary El
# GOT EMBEDDING FOR True crime writer El
# GOT EMBEDDING FOR After eight months o
# GOT EMBEDDING FOR A young woman named
# GOT EMBEDDING FOR Heather Mason (Adela
# GOT EMBEDDING FOR In Berkeley, Califor
# GOT EMBEDDING FOR In New York City, a
# GOT EMBEDDING FOR Best friends Chon (T
# GOT EMBEDDING FOR Darius Britt (Aubrey
# GOT EMBEDDING FOR In Cape Town, South
# GOT EMBEDDING FOR Ex-cop and cage figh
# GOT EMBEDDING FOR Calvin Weir-Fields (
# GOT EMBEDDING FOR In 1987, Sherrie Chr
# GOT EMBEDDING FOR Set in the near futu
# GOT EMBEDDING FOR Jack Frost awakens f
# GOT EMBEDDING FOR Alice and the others
# GOT EMBEDDING FOR In 2011, Anse Rainie
# GOT EMBEDDING FOR In 1944, as the air
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR An introductory mont
# GOT EMBEDDING FOR In 19th-century Balt
# GOT EMBEDDING FOR The film opens as Lo
# GOT EMBEDDING FOR Ozu, the villain fro
# GOT EMBEDDING FOR As a spacecraft depa
# GOT EMBEDDING FOR In Pasadena, high sc
# GOT EMBEDDING FOR Pete Cozy (Eric Mabi
# GOT EMBEDDING FOR The film has a nonli
# GOT EMBEDDING FOR A newly separated co
# GOT EMBEDDING FOR In Los Angeles, subs
# GOT EMBEDDING FOR Detroit, Michigan: 1
# GOT EMBEDDING FOR The Trade Federation
# GOT EMBEDDING FOR An aging Atlanta Bra
# GOT EMBEDDING FOR Maya is a U.S. Centr
# GOT EMBEDDING FOR When Matt moved to H
# GOT EMBEDDING FOR When Litwak's Family
# GOT EMBEDDING FOR Perseus (Sam Worthin
# GOT EMBEDDING FOR Clayton Hammond (Den
# GOT EMBEDDING FOR Set in Atlanta,[4] t
# GOT EMBEDDING FOR In the town of Glenv
# GOT EMBEDDING FOR George and Linda Ger
# GOT EMBEDDING FOR Paige Collins (Rache
# GOT EMBEDDING FOR In a small town, men
# GOT EMBEDDING FOR The film is presente
# GOT EMBEDDING FOR A few years after th
# GOT EMBEDDING FOR The setting begins w
# GOT EMBEDDING FOR The film starts on O
# GOT EMBEDDING FOR At the end of the 21
# GOT EMBEDDING FOR In 1996, treasure hu
# GOT EMBEDDING FOR Brian is a 16-year-o
# GOT EMBEDDING FOR The film is composed
# GOT EMBEDDING FOR CIA agents and best
# GOT EMBEDDING FOR While having sex in
# GOT EMBEDDING FOR The film follows fou
# GOT EMBEDDING FOR In 1984, middle scho
# GOT EMBEDDING FOR In 1985, eight-year-
# GOT EMBEDDING FOR Julia lives in a sma
# GOT EMBEDDING FOR At the funeral of hi
# GOT EMBEDDING FOR Princess Odette and
# GOT EMBEDDING FOR In New Orleans, Will
# GOT EMBEDDING FOR At the 2011 ICCA Fin
# GOT EMBEDDING FOR Jack McCall (Eddie M
# GOT EMBEDDING FOR The film is set agai
# GOT EMBEDDING FOR Jesse Fischer (Radno
# GOT EMBEDDING FOR As the Fugue String
# GOT EMBEDDING FOR In West Dallas, Texa
# GOT EMBEDDING FOR In 1998, Erik, a Dan
# GOT EMBEDDING FOR After the untimely d
# GOT EMBEDDING FOR It has been four yea
# GOT EMBEDDING FOR In 1881, Edgar Rice
# GOT EMBEDDING FOR Jeff (Segel) is a 30
# GOT EMBEDDING FOR In Pittsburgh, Penns
# GOT EMBEDDING FOR While Scrat inadvert
# GOT EMBEDDING FOR As punishment for a
# GOT EMBEDDING FOR A newly divorced med
# GOT EMBEDDING FOR In 1895, in the afte
# GOT EMBEDDING FOR Although a devoted c
# GOT EMBEDDING FOR Charlie Bronson (Dax
# GOT EMBEDDING FOR High school valedict
# GOT EMBEDDING FOR In the 1980s, a girl
# GOT EMBEDDING FOR Former Division I co
# GOT EMBEDDING FOR Former Marine Mallor
# GOT EMBEDDING FOR Andy Brewster (Seth
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Jillian "Jill" Conwa
# GOT EMBEDDING FOR Frank Murdoch (Joel
# GOT EMBEDDING FOR Grace is a single mo
# GOT EMBEDDING FOR In Romania, a French
# GOT EMBEDDING FOR Jenn (played by Jenn
# GOT EMBEDDING FOR British art curator
# GOT EMBEDDING FOR In Cleveland, Ohio,[
# GOT EMBEDDING FOR Jason (an advertisin
# GOT EMBEDDING FOR Sam Harper (Chris Pi
# GOT EMBEDDING FOR In 1931, the Bondura
# GOT EMBEDDING FOR John Ottway (Liam Ne
# GOT EMBEDDING FOR In Canada, novelist
# GOT EMBEDDING FOR Freddie Quell is a W
# GOT EMBEDDING FOR When her husband tel
# GOT EMBEDDING FOR In January 1865, Pre
# GOT EMBEDDING FOR Artie Decker, a spor
# GOT EMBEDDING FOR In the small town of
# GOT EMBEDDING FOR On October 9, 2006,
# GOT EMBEDDING FOR Anita (Macy Gray), t
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Stephanie Plum, out
# GOT EMBEDDING FOR The film is told fro
# GOT EMBEDDING FOR  23-year-old Martine
# GOT EMBEDDING FOR In September 1965, o
# GOT EMBEDDING FOR The city of Monstrop
# GOT EMBEDDING FOR Snow White's widowed
# GOT EMBEDDING FOR In 2012, an alien cr
# GOT EMBEDDING FOR The story is narrate
# GOT EMBEDDING FOR In nineteenth centur
# GOT EMBEDDING FOR Many days after bidd
# GOT EMBEDDING FOR In 2079, CIA agent S
# GOT EMBEDDING FOR Young scientist Vict
# GOT EMBEDDING FOR In New York City, Ni
# GOT EMBEDDING FOR Alex (Gael Garcia Be
# GOT EMBEDDING FOR In 2044, 25-year-old
# GOT EMBEDDING FOR Logan Thibault (Zac
# GOT EMBEDDING FOR Ted Wiggins is a 12-
# GOT EMBEDDING FOR George Needleman, a
# GOT EMBEDDING FOR Mike (Channing Tatum
# GOT EMBEDDING FOR Monte Wildhorn (Free
# GOT EMBEDDING FOR Maladies is divided
# GOT EMBEDDING FOR British medical stud
# GOT EMBEDDING FOR Jamie Rellis (Mila K
# GOT EMBEDDING FOR Britt Reid is the pl
# GOT EMBEDDING FOR Eric (Jason Sudeikis
# GOT EMBEDDING FOR In Stratford-Upon-Av
# GOT EMBEDDING FOR In Stockholm, Sweden
# GOT EMBEDDING FOR Billions of years ag
# GOT EMBEDDING FOR The story involves a
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Charley Brewster is
# GOT EMBEDDING FOR Salesman Nick Halsey
# GOT EMBEDDING FOR After a long night o
# ...
# GOT EMBEDDING FOR Italian woodcarver G
# GOT EMBEDDING FOR While the Genie and
# GOT EMBEDDING FOR The plot follows hum
# GOT EMBEDDING FOR An explosive situati
# GOT EMBEDDING FOR In this movie, detec
# GOT EMBEDDING FOR Charlie B. Barkin (C
# GOT EMBEDDING FOR Newlyweds Bill and C
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR The film starts with
# GOT EMBEDDING FOR Investment banker La
# GOT EMBEDDING FOR Corky (Gina Gershon)
# GOT EMBEDDING FOR John Baker Jr. (Luka
# GOT EMBEDDING FOR Four intellectually
# GOT EMBEDDING FOR Gabriela (Angela Jon
# GOT EMBEDDING FOR In New York City, De
# GOT EMBEDDING FOR While serving in the
# GOT EMBEDDING FOR Sarah Bailey, a trou
# GOT EMBEDDING FOR College student Joe
# GOT EMBEDDING FOR In Los Angeles, mech
# GOT EMBEDDING FOR Early one morning in
# GOT EMBEDDING FOR The film opens as th
# GOT EMBEDDING FOR The film is set in t
# GOT EMBEDDING FOR The cliffhanger endi
# GOT EMBEDDING FOR In upstate New York,
# GOT EMBEDDING FOR Eliza (Davis) discov
# GOT EMBEDDING FOR Sergeant Dutton Hatf
# GOT EMBEDDING FOR Tom Turner, a con ar
# GOT EMBEDDING FOR A group of terrorist
# GOT EMBEDDING FOR The movie opens with
# GOT EMBEDDING FOR Grace Rhodes is a me
# GOT EMBEDDING FOR Bess McNeill is a pr
# GOT EMBEDDING FOR Frank 'Rhino' Rhinos
# GOT EMBEDDING FOR Major Vic Deakins (J
# GOT EMBEDDING FOR Butch "Bullet" Stein
# GOT EMBEDDING FOR Archie Moses is a sm
# GOT EMBEDDING FOR The police force of
# GOT EMBEDDING FOR Matt Grabowski (Denn
# GOT EMBEDDING FOR After a failed marri
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR When greedy land-gra
# GOT EMBEDDING FOR In the opening seque
# GOT EMBEDDING FOR Workaholic advertisi
# GOT EMBEDDING FOR Joseph Svenden is a
# GOT EMBEDDING FOR Best friends for lif
# GOT EMBEDDING FOR Eddie Kasalivich (Ke
# GOT EMBEDDING FOR In April 1967, the o
# GOT EMBEDDING FOR Act One: Jake is a s
# GOT EMBEDDING FOR A counterfeiter of m
# GOT EMBEDDING FOR Jane Eyre (portrayed
# GOT EMBEDDING FOR Nightclub manager Da
# GOT EMBEDDING FOR On a summer night in
# GOT EMBEDDING FOR At a corporation's b
# GOT EMBEDDING FOR The story centers on
# GOT EMBEDDING FOR Secret agent WD-40 D
# GOT EMBEDDING FOR It is the 24th centu
# GOT EMBEDDING FOR Lucy Harmon, a ninet
# GOT EMBEDDING FOR Former FBI secretary
# GOT EMBEDDING FOR Joan and Stanley Stu
# GOT EMBEDDING FOR Jonathan Shale (Bere
# GOT EMBEDDING FOR "Blue" Monroe (playe
# GOT EMBEDDING FOR Phyllis Saroka (Perl
# GOT EMBEDDING FOR The young Françoise
# GOT EMBEDDING FOR In the fictional tow
# GOT EMBEDDING FOR Mike Peters is a str
# GOT EMBEDDING FOR Diane Shepherd is an
# GOT EMBEDDING FOR Psychologist Jon Por
# GOT EMBEDDING FOR Solo (Van Peebles) i
# GOT EMBEDDING FOR A competition is hel
# GOT EMBEDDING FOR Francesca "Frankie"
# GOT EMBEDDING FOR In Verona Beach, the
# GOT EMBEDDING FOR The movie centers ar
# GOT EMBEDDING FOR Samson is chosen by
# GOT EMBEDDING FOR The story is about a
# GOT EMBEDDING FOR Blake Thorn (Hulk Ho
# GOT EMBEDDING FOR High school student
# GOT EMBEDDING FOR Master Sergeant Erne
# GOT EMBEDDING FOR Karl Childers is an
# GOT EMBEDDING FOR She Cried No tells t
# GOT EMBEDDING FOR Irish Catholic Micke
# GOT EMBEDDING FOR An unnamed abused do
# GOT EMBEDDING FOR The movie takes plac
# GOT EMBEDDING FOR Skin & Bone is an ep
# GOT EMBEDDING FOR Lorenzo "Shakes" Car
# GOT EMBEDDING FOR In 1964, in Erie, Pe
# GOT EMBEDDING FOR Billy Halleck (Rober
# GOT EMBEDDING FOR The events depicted
# GOT EMBEDDING FOR In the fictional tow
# GOT EMBEDDING FOR Mildred (Gena Rowlan
# GOT EMBEDDING FOR Parton stars as a so
# GOT EMBEDDING FOR Sally "Tally" Atwate
# GOT EMBEDDING FOR One evening, a man c
# GOT EMBEDDING FOR Jerry Maguire (Tom C
# GOT EMBEDDING FOR Jeremy Collier is a
# GOT EMBEDDING FOR Cheryl is a young, A
# GOT EMBEDDING FOR Archaeologists worki
# GOT EMBEDDING FOR The film is based on
# GOT EMBEDDING FOR In 1933 Texas school
# GOT EMBEDDING FOR The Windsor Protocol
# GOT EMBEDDING FOR Phillip is a naive n
# GOT EMBEDDING FOR The two Wheaton sist
# GOT EMBEDDING FOR Intelligent aliens w
# GOT EMBEDDING FOR Dr. David Krane (Ray
# GOT EMBEDDING FOR Art Dodge (Antonio B
# GOT EMBEDDING FOR One stormy night in
# GOT EMBEDDING FOR Phillip and Dieter n
# GOT EMBEDDING FOR Roy "Tin Cup" McAvoy
# GOT EMBEDDING FOR Titanic follows thre
# GOT EMBEDDING FOR Set in 1979, the fil
# GOT EMBEDDING FOR David Lewis (Peter G
# GOT EMBEDDING FOR Mark Thackeray (Sidn
# GOT EMBEDDING FOR This film follows th
# GOT EMBEDDING FOR Jake Thorne (Bruce C
# GOT EMBEDDING FOR Jennifer Stanton (Ha
# GOT EMBEDDING FOR Tommy Basilio is an
# GOT EMBEDDING FOR A man on an oil fiel
# GOT EMBEDDING FOR Annie and Matthew, a
# GOT EMBEDDING FOR A wealthy man by the
# GOT EMBEDDING FOR Set in modern-day Ma
# GOT EMBEDDING FOR Abby Barnes (Garofal
# GOT EMBEDDING FOR A group of rogue U.S
# GOT EMBEDDING FOR Amelia (Keener) and
# GOT EMBEDDING FOR Josie Potenza is the
# GOT EMBEDDING FOR Set in 1960, the sto
# GOT EMBEDDING FOR Faith Ferguson (Mimi
# GOT EMBEDDING FOR At Loch Ness, Scotla
# GOT EMBEDDING FOR Sheriff Sam Deeds is
# GOT EMBEDDING FOR Samantha Caine (Geen
# GOT EMBEDDING FOR Love Is All There Is
# GOT EMBEDDING FOR Michael Walsh, a hus
# GOT EMBEDDING FOR In Kentucky, a famil
# GOT EMBEDDING FOR A man who had a stro
# GOT EMBEDDING FOR Mary Reilly comes to
# GOT EMBEDDING FOR Matilda Wormwood is
# GOT EMBEDDING FOR Alain Moreau (Jean-C
# GOT EMBEDDING FOR The year is 2015 and
# GOT EMBEDDING FOR Although the opening
# GOT EMBEDDING FOR David discovers ever
# GOT EMBEDDING FOR The founder of virtu
# GOT EMBEDDING FOR In 1922, Joe O'Reill
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR In 1991, the remains
# GOT EMBEDDING FOR Howard Langston is a
# GOT EMBEDDING FOR Penniless and straig
# GOT EMBEDDING FOR It's Christmas Eve a
# GOT EMBEDDING FOR Annie Laird (Demi Mo
# GOT EMBEDDING FOR Set in 16th century
# GOT EMBEDDING FOR The book details Ame
# GOT EMBEDDING FOR Behind-the-scenes ne
# GOT EMBEDDING FOR Flashy young bowler
# GOT EMBEDDING FOR Littlefoot notices a
# GOT EMBEDDING FOR The film opens at a
# GOT EMBEDDING FOR Cindy Liggett (Sharo
# GOT EMBEDDING FOR Frankie (Dennis Hopp
# GOT EMBEDDING FOR In 1932 Prohibition-
# GOT EMBEDDING FOR The National Mirror
# GOT EMBEDDING FOR A kidnapping goes do
# GOT EMBEDDING FOR Rose Morgan (Streisa
# GOT EMBEDDING FOR The film revolves ar
# GOT EMBEDDING FOR In 1952, 10-year-old
# GOT EMBEDDING FOR In the early 16th ce
# GOT EMBEDDING FOR During a glorious So
# GOT EMBEDDING FOR George Malley is a k
# GOT EMBEDDING FOR Despite the evidence
# GOT EMBEDDING FOR Lily is a sheltered
# GOT EMBEDDING FOR Isabel Archer, origi
# GOT EMBEDDING FOR Tom Thompson (David
# GOT EMBEDDING FOR A voiceover by the c
# GOT EMBEDDING FOR Martin Vail (Richard
# GOT EMBEDDING FOR Late night in an emp
# GOT EMBEDDING FOR A new science teache
# GOT EMBEDDING FOR Years after the even
# GOT EMBEDDING FOR While multi-milliona
# GOT EMBEDDING FOR The story begins in
# GOT EMBEDDING FOR Sexually abused by h
# GOT EMBEDDING FOR Julie Longwell, the
# GOT EMBEDDING FOR In the early 1950s,
# GOT EMBEDDING FOR The movie opens to a
# GOT EMBEDDING FOR John Henderson (Albe
# GOT EMBEDDING FOR A former divorcé lea
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR Al McCord is hanging
# GOT EMBEDDING FOR Establishing shot of
# GOT EMBEDDING FOR Confined in an Israe
# GOT EMBEDDING FOR Doug Kinney (Michael
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Melanie Parker (Mich
# GOT EMBEDDING FOR At Wellman College,
# GOT EMBEDDING FOR Moll's mother is a c
# GOT EMBEDDING FOR Republican Senator R
# GOT EMBEDDING FOR Jim Hawkins is a you
# GOT EMBEDDING FOR Chili Palmer, a loan
# GOT EMBEDDING FOR Fifteen-year-old Ang
# GOT EMBEDDING FOR Tommy Fawkes is the
# GOT EMBEDDING FOR Claudia is the middl
# GOT EMBEDDING FOR John "J. J." Johnson
# GOT EMBEDDING FOR A fastidious and who
# GOT EMBEDDING FOR It's been two years
# GOT EMBEDDING FOR The film is set on N
# GOT EMBEDDING FOR At a restaurant in N
# GOT EMBEDDING FOR Fluke is a mutt pupp
# GOT EMBEDDING FOR In New York, Bill (B
# GOT EMBEDDING FOR The film's opening t
# GOT EMBEDDING FOR The film begins five
# GOT EMBEDDING FOR Craig Jones, a young
# GOT EMBEDDING FOR The title character
# GOT EMBEDDING FOR Three friends decide
# GOT EMBEDDING FOR Kathryn "Kate" McQue
# GOT EMBEDDING FOR An enigmatic, homele
# GOT EMBEDDING FOR Teenage computer whi
# GOT EMBEDDING FOR Empire Records is an
# GOT EMBEDDING FOR The pair of Bobby Ke
# GOT EMBEDDING FOR Solicitor Thomas Ren
# GOT EMBEDDING FOR Richard Jacks (Tim D
# GOT EMBEDDING FOR Teenage lovers Jorda
# GOT EMBEDDING FOR Psychiatrist Jack Mi
# GOT EMBEDDING FOR In 1995, Dolores Cla
# GOT EMBEDDING FOR It is the last day o
# GOT EMBEDDING FOR In New York City, th
# GOT EMBEDDING FOR In the summer of 194
# GOT EMBEDDING FOR In June 1980, Beth E
# GOT EMBEDDING FOR Claudia Larson, a si
# GOT EMBEDDING FOR A piglet named Gordy
# GOT EMBEDDING FOR Terri Venessi (Mary
# GOT EMBEDDING FOR The film opens in a
# GOT EMBEDDING FOR A woman, having rece
# GOT EMBEDDING FOR The story takes plac
# GOT EMBEDDING FOR Set in the period 17
# GOT EMBEDDING FOR San Francisco Assist
# GOT EMBEDDING FOR The Kelly family liv
# GOT EMBEDDING FOR Two unrelated young
# GOT EMBEDDING FOR On his ninth birthda
# GOT EMBEDDING FOR It is spring. Randy
# GOT EMBEDDING FOR In the midst of an u
# GOT EMBEDDING FOR A crafty nightclub o
# GOT EMBEDDING FOR In a black-and-white
# GOT EMBEDDING FOR Paul Racine, a compu
# GOT EMBEDDING FOR Kevin Franklin (Sinb
# GOT EMBEDDING FOR Set in a remote dese
# GOT EMBEDDING FOR At fictitious Columb
# GOT EMBEDDING FOR After killing two wo
# GOT EMBEDDING FOR The Munster family i
# GOT EMBEDDING FOR As school ends for t
# GOT EMBEDDING FOR The film begins at P
# GOT EMBEDDING FOR Neil McCauley, a car
# GOT EMBEDDING FOR In 1928 England, Dav
# GOT EMBEDDING FOR Harrison Bergeron li
# GOT EMBEDDING FOR On October 31, 1989,
# GOT EMBEDDING FOR In 1988, 11-year-old
# GOT EMBEDDING FOR When the Blockheads'
# GOT EMBEDDING FOR The feud between Max
# GOT EMBEDDING FOR At the Tarasco bar i
# GOT EMBEDDING FOR Darcy Walker (Joan S
# GOT EMBEDDING FOR In the spring of 196
# GOT EMBEDDING FOR Babe, an orphaned pi
# GOT EMBEDDING FOR Air Force courier Ni
# GOT EMBEDDING FOR Billy Madison is the
# GOT EMBEDDING FOR Teacher Anna Montgom
# GOT EMBEDDING FOR Andy Bowman persuade
# GOT EMBEDDING FOR The film starts on J
# GOT EMBEDDING FOR Baywatch lifeguards
# GOT EMBEDDING FOR In Gotham City, the
# GOT EMBEDDING FOR The film is an adapt
# GOT EMBEDDING FOR In New York City, an
# GOT EMBEDDING FOR Former CIA agent Nel
# GOT EMBEDDING FOR Miami detectives Mar
# GOT EMBEDDING FOR Kristy Thomas, presi
# GOT EMBEDDING FOR The three finalists
# GOT EMBEDDING FOR Matthew Poncelet has
# GOT EMBEDDING FOR Robert Rath (Sylvest
# GOT EMBEDDING FOR In July 1969, astron
# GOT EMBEDDING FOR Angus Bethune (Talbe
# GOT EMBEDDING FOR William Adamson (Mar
# GOT EMBEDDING FOR Angela is a 10-year-
# GOT EMBEDDING FOR Popular Democratic P
# GOT EMBEDDING FOR Ryan Tyler's father
# GOT EMBEDDING FOR Amanda, an employee
# GOT EMBEDDING FOR Kathleen Conklin (Ta
# GOT EMBEDDING FOR In the Himalayas, af
# GOT EMBEDDING FOR Christopher Reeve st
# GOT EMBEDDING FOR Rocky (Michael Trean
# GOT EMBEDDING FOR Joseph, a Hebrew, is
# GOT EMBEDDING FOR The film once again
# GOT EMBEDDING FOR Rick Heller is a juv
# GOT EMBEDDING FOR Three unique women e
# GOT EMBEDDING FOR Larry Dittmeyer, an
# GOT EMBEDDING FOR William Blake (Johnn
# GOT EMBEDDING FOR LouAnne Johnson (Mic
# GOT EMBEDDING FOR Crime boss Jesse Sta
# GOT EMBEDDING FOR In 1668 Jamaica, Mor
# GOT EMBEDDING FOR Set in a small town
# GOT EMBEDDING FOR Set in South Africa
# GOT EMBEDDING FOR Freddy Gale (Nichols
# GOT EMBEDDING FOR In post-Soviet Russi
# GOT EMBEDDING FOR After giving a guest
# GOT EMBEDDING FOR While testing a comm
# GOT EMBEDDING FOR Cosmo Reif, an affec
# GOT EMBEDDING FOR Cheryl "Cher" Horowi
# GOT EMBEDDING FOR In a Brooklyn, New Y
# GOT EMBEDDING FOR A body is discovered
# GOT EMBEDDING FOR Eli and Joshua are b
# GOT EMBEDDING FOR A young German Princ
# GOT EMBEDDING FOR After inheriting a 1
# GOT EMBEDDING FOR In the town of Frien
# GOT EMBEDDING FOR In 1973, sports hand
# GOT EMBEDDING FOR At the Yucca Mountai
# GOT EMBEDDING FOR Coleman Tarrant, the
# GOT EMBEDDING FOR Thousands of former
# GOT EMBEDDING FOR This is a story abou
# GOT EMBEDDING FOR Deliveryman "Mad" Ma
# GOT EMBEDDING FOR The film begins with
# GOT EMBEDDING FOR In the present, adul
# GOT EMBEDDING FOR In 1280, King Edward
# GOT EMBEDDING FOR In 2021, Johnny is a
# GOT EMBEDDING FOR Nina, an art dealer,
# GOT EMBEDDING FOR By the 2080s, much o
# GOT EMBEDDING FOR Nomi Malone is a you
# GOT EMBEDDING FOR In 2022, a comet str
# GOT EMBEDDING FOR Amy Winslow (Alyssa
# GOT EMBEDDING FOR Darren McCord (Jean-
# GOT EMBEDDING FOR Stuart Smalley (Al F
# GOT EMBEDDING FOR In the last two days
# GOT EMBEDDING FOR Matty Dean, a young
# GOT EMBEDDING FOR The setting is early
# GOT EMBEDDING FOR During the SETI prog
# GOT EMBEDDING FOR The film shows a sce
# GOT EMBEDDING FOR The film follows the
# GOT EMBEDDING FOR Seventeen years afte
# GOT EMBEDDING FOR Ernest takes a job w
# GOT EMBEDDING FOR Billy, a young skinh
# GOT EMBEDDING FOR Charlie Thorpe (Bill
# GOT EMBEDDING FOR Junior Healy (Justin
# GOT EMBEDDING FOR Soon-to-retire detec
# GOT EMBEDDING FOR On his deathbed, Mr.
# GOT EMBEDDING FOR In the year 2078, th
# GOT EMBEDDING FOR It is 1667 in the Ma
# GOT EMBEDDING FOR Japanese theaters sh
# GOT EMBEDDING FOR Set in an affluent n
# GOT EMBEDDING FOR Sabrina Fairchild is
# GOT EMBEDDING FOR Minnie visits Mickey
# GOT EMBEDDING FOR In 1963 Pittsburgh,
# GOT EMBEDDING FOR In Scotland, 1713, R
# GOT EMBEDDING FOR A young doctor, Robe
# GOT EMBEDDING FOR Relentlessly cheerfu
# GOT EMBEDDING FOR An unnamed gunslinge
# GOT EMBEDDING FOR In an alternate futu
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Jimmy "The Saint" To
# GOT EMBEDDING FOR In the present, a fa
# GOT EMBEDDING FOR In 1869, near Brantf
# GOT EMBEDDING FOR It is based on the t
# GOT EMBEDDING FOR In 1920s South Ameri
# GOT EMBEDDING FOR A well-known lawman
# GOT EMBEDDING FOR The movie begins wit
# GOT EMBEDDING FOR Lucy Eleanor Moderat
# GOT EMBEDDING FOR Eleven-and-a-half-ye
# GOT EMBEDDING FOR Long after the melti
# GOT EMBEDDING FOR In 1972 North Vietna
# GOT EMBEDDING FOR In 1945, after World
# GOT EMBEDDING FOR "Friends are the Peo
# GOT EMBEDDING FOR In Los Angeles, Lt.
# GOT EMBEDDING FOR All of the people, a
# GOT EMBEDDING FOR An abandoned ship cr
# GOT EMBEDDING FOR The film opens with
# GOT EMBEDDING FOR Michael Chambers ret
# GOT EMBEDDING FOR Casey Ryback retires
# GOT EMBEDDING FOR It is a hot summer d
# GOT EMBEDDING FOR A deadly virus relea
# GOT EMBEDDING FOR In a world where toy
# GOT EMBEDDING FOR The film opens as tw
# GOT EMBEDDING FOR After seven years at
# GOT EMBEDDING FOR The movie opens with
# GOT EMBEDDING FOR Anna Nicole Smith pl
# GOT EMBEDDING FOR After tying for the
# GOT EMBEDDING FOR Suzanne Stone dreams
# GOT EMBEDDING FOR In California, John
# GOT EMBEDDING FOR Thomas Dagget, a Cat
# GOT EMBEDDING FOR Bruno Buckingham is
# GOT EMBEDDING FOR Stan Dryer, an unsuc
# GOT EMBEDDING FOR In Seattle, straight
# GOT EMBEDDING FOR Rebecca Lott is a th
# GOT EMBEDDING FOR On Christmas, we mee
# GOT EMBEDDING FOR The Power Rangers pa
# GOT EMBEDDING FOR The film opens on an
# GOT EMBEDDING FOR The story is set in
# GOT EMBEDDING FOR Gwyn Marcus (Sarah J
# GOT EMBEDDING FOR Set in the 1940s in
# GOT EMBEDDING FOR A police detective i
# GOT EMBEDDING FOR Six-year-old Ben Arc
# GOT EMBEDDING FOR College student T.S.
# GOT EMBEDDING FOR U.S. Marine Corps Ma
# GOT EMBEDDING FOR Jack Carlisle is a d
# GOT EMBEDDING FOR Ashley Black is depr
# GOT EMBEDDING FOR While craving her ne
# GOT EMBEDDING FOR Mortal Kombat is a f
# GOT EMBEDDING FOR In the Mojave Desert
# GOT EMBEDDING FOR The film is divided
# GOT EMBEDDING FOR In the year 1914, Sa
# GOT EMBEDDING FOR A college freshman R
# GOT EMBEDDING FOR Ben Sanderson is a H
# GOT EMBEDDING FOR Distraught but skill
# GOT EMBEDDING FOR One day, a shower of
# GOT EMBEDDING FOR Jimmy Kilmartin is a
# GOT EMBEDDING FOR Telly and a 12-year-
# GOT EMBEDDING FOR Allan Breck Stewart
# GOT EMBEDDING FOR Paul Armstrong (Sean
# GOT EMBEDDING FOR Jeremy "Powder" Reed
# GOT EMBEDDING FOR Tommy Collins is an
# GOT EMBEDDING FOR Calvin Fuller is a n
# GOT EMBEDDING FOR In Portland, Oregon
# GOT EMBEDDING FOR During the Vietnam W

# %%
data = movies[['Title', 'Genre']].to_dict('records')

# %%
# !pip install nomic
# Out:
# Collecting nomic
#   Downloading nomic-3.1.2.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nomic) (8.1.7)
# Collecting jsonlines (from nomic)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting loguru (from nomic)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from nomic) (13.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nomic) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nomic) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nomic) (2.2.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from nomic) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nomic) (4.66.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from nomic) (16.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from nomic) (10.4.0)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.10/dist-packages (from nomic) (2.9.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->nomic) (24.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->nomic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nomic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->nomic) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->nomic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->nomic) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->nomic) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->nomic) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nomic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nomic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nomic) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->nomic) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->nomic) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->nomic) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->nomic) (1.16.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: nomic
#   Building wheel for nomic (pyproject.toml) ... done
#   Created wheel for nomic: filename=nomic-3.1.2-py3-none-any.whl size=46220 sha256=1f2f96c9886f6e9920adf0c66fcc5cbd19a19685a5150acaf047b856b0b0346b
#   Stored in directory: /root/.cache/pip/wheels/32/d2/d8/50ce795e97e02860977823a8ccf31460cabb23c6cf33a070ae
# Successfully built nomic
# Installing collected packages: loguru, jsonlines, nomic
# Successfully installed jsonlines-4.0.0 loguru-0.7.2 nomic-3.1.2

# %%
from nomic import atlas
import nomic
import numpy as np

# %%
nomic.login(userdata.get('NOMIC_API_TOKEN'))

# %%
project = atlas.map_data(
    embeddings=np.array(plot_embeddings),
    data=data,
)
# Out:
# 2024-10-22 00:51:30.718 | INFO     | nomic.dataset:_create_project:857 - Creating dataset `logical-ramanujan`
# 2024-10-22 00:51:30.858 | INFO     | nomic.atlas:map_data:140 - Uploading data to Atlas.
# 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# 2024-10-22 00:51:33.027 | INFO     | nomic.dataset:_add_data:1668 - Upload succeeded.
# 2024-10-22 00:51:33.028 | INFO     | nomic.atlas:map_data:158 - `naoki/logical-ramanujan`: Data upload succeeded to dataset`
# 2024-10-22 00:51:33.251 | WARNING  | nomic.dataset:create_index:1111 - You did not specify the `topic_label_field` option in your topic_model, your dataset will not contain auto-labeled topics.
# 2024-10-22 00:51:33.833 | INFO     | nomic.dataset:create_index:1262 - Created map `logical-ramanujan` in dataset `naoki/logical-ramanujan`: https://atlas.nomic.ai/data/naoki/logical-ramanujan

# %%
from typing import List, Optional
from scipy import spatial

def distances_from_embeddings(
    query_embedding: List[float],
    embeddings: List[List[float]],
    distance_metric="cosine",
) -> List[List]:
    """Return the distances between a query embedding and a list of embeddings."""
    distance_metrics = {
        "cosine": spatial.distance.cosine,
        "L1": spatial.distance.cityblock,
        "L2": spatial.distance.euclidean,
        "Linf": spatial.distance.chebyshev,
    }
    distances = [
        distance_metrics[distance_metric](query_embedding, embedding)
        for embedding in embeddings
    ]
    return distances


def indices_of_nearest_neighbors_from_distances(distances) -> np.ndarray:
  """Return a list of indices of nearest neighbors from a list of distances."""
  return np.argsort(distances)

# %%
def print_recommendations_from_strings(
    strings,
    index_of_source_string,
    k_nearest_neighbors=3,
    model='text-embedding-ada-002'
):
  # Get all of the embeddings
  embeddings = [embedding_from_string(string) for string in strings]
  # get embedding for our specific query string
  query_embedding = embeddings[index_of_source_string]
  # get distances between our embedding and all other embeddings
  distances = distances_from_embeddings(query_embedding, embeddings)
  print(distances)
  # ge indices of the nearest neighbors
  indices_of_nearest_neighbors = indices_of_nearest_neighbors_from_distances(distances)
  query_string = strings[index_of_source_string]
  match_count = 0
  for i in indices_of_nearest_neighbors:
    if query_string == strings[i]:
      continue
    if match_count >= k_nearest_neighbors:
      break
    match_count += 1
    print(f'\nFound {match_count} closest match')
    print(f"Distance of {distances[i]}")
    print(strings[i])

# %%
print_recommendations_from_strings(movie_plots, 2)
# Out:
# [0.2518517182864721, 0.24701209411519698, 0.0, 0.23095605608559755, 0.2343782703980325, 0.24754564483961206, 0.22776189538149005, 0.24703127335440567, 0.2298327701762537, 0.18793624576101198, 0.25728992930031114, 0.2604211661090994, 0.2469218679177544, 0.2094798543471672, 0.24137044502532723, 0.2863864101552428, 0.2612565706596256, 0.2490906606555815, 0.24663778962598149, 0.20250460108479573, 0.2026195150201886, 0.22929903127902518, 0.25206550809093975, 0.20876366413683511, 0.25310278711278533, 0.27562548155017197, 0.2403552574587947, 0.2657675498820934, 0.24188004705396737, 0.23531991776489436, 0.25419594796892775, 0.24601872235143196, 0.24061528690646605, 0.20972378711420636, 0.26367269031542084, 0.23565906055335561, 0.200983785297691, 0.2405650536703441, 0.2482772943736682, 0.25871377269722096, 0.2525365396942907, 0.2504317080382624, 0.24862568023906562, 0.25325599744185523, 0.25122992330022154, 0.21705785582320103, 0.21310881800941206, 0.2363194643111367, 0.24839485026398622, 0.21729514871307298, 0.24161139766488182, 0.22259812611681007, 0.26478528474101926, 0.21066057832672702, 0.22736110940545906, 0.26077108648366165, 0.2056461598663728, 0.2237885416659512, 0.208390878943443, 0.2587686908324681, 0.2505994694798723, 0.2669526480640676, 0.23762354012178422, 0.16356843987197622, 0.2342551182155761, 0.23129247833
# The Prometheus lands on the barren, mountainous surface near a large, artificial structure, which a team explores. Inside, they find stone cylinders, a monolithic statue of a humanoid head, and the decapitated corpse of a large alien, thought to be an Engineer; Shaw recovers its head. The crew finds other bodies, leading them to surmise the species is extinct. Crew members Millburn and Fifield grow uncomfortable with the discoveries and attempt to return to Prometheus, but become stranded in the structure when they get lost. The expedition is cut short when a storm forces the crew to return to the ship. David secretly takes a cylinder from the structure, while the remaining cylinders begin leaking a dark liquid. In the ship's lab, the Engineer's DNA is found to match that of humans. David investigates the cylinder and the liquid inside. He intentionally taints a drink with the liquid and gives it to the unsuspecting Holloway, who had stated he would do anything for answers. Shortly after, Shaw and Holloway have sex.
# Inside the structure, a snake-like creature kills Millburn and sprays a corrosive fluid that melts Fifield's helmet. Fifield falls face-first into a puddle of dark liquid. When the crew returns, they find Millburn's corpse. David separately discovers a control room containing a surviving Engineer in stasis, and a large 3D holographic star map highlighting Earth. Meanwhile, Holloway sickens rapidly. He is rushed back to Prometheus, but Vickers refuses to let him aboard, and at his urging, burns him to death with a flamethrower. Later, a medical scan reveals that Shaw, despite being sterile, is pregnant. Fearing the worst, she uses an automated surgery table to extract a squid-like creature from her abdomen. Shaw then discovers that Weyland has been in stasis aboard Prometheus. He explains that he wants to ask the Engineers to prevent his death from old age. As Weyland prepares to leave for the structure, Vickers addresses him as "Father".
# A monstrous, mutated Fifield returns to the Prometheus and kills several crew members before he is killed. The Prometheus' captain, Janek, speculates that the structure was an Engineer military base that lost control of a virulent biological weapon, the dark liquid. He also determines that the structure houses a spacecraft. Weyland and a team return to the structure, accompanied by Shaw. David wakes the Engineer from stasis and speaks to him in an attempt to explain what Weyland wants. The Engineer responds by decapitating David and killing Weyland and his team, before reactivating the spacecraft. Shaw flees and warns Janek that the Engineer is planning to release the liquid on Earth, convincing him to stop the spacecraft. Janek and the remaining crew sacrifice themselves by ramming the Prometheus into the alien craft, ejecting the lifeboat in the process, while Vickers flees in an escape pod. The Engineer's disabled spacecraft crashes onto the ground, killing Vickers. Shaw goes to the lifeboat and finds her alien offspring is alive and has grown to gigantic size. David's still-active head warns Shaw that the Engineer is pursuing her. The Engineer forces open the lifeboat's airlock and attacks Shaw, who releases her alien offspring onto the Engineer; it thrusts an ovipositor down the Engineer's throat, subduing him. Shaw recovers David's remains, and with his help, launches another Engineer spacecraft. She intends to reach the Engineers' homeworld in an attempt to understand why they wanted to destroy humanity.
# In the lifeboat, an alien creature bursts out of the Engineer's chest.
#
# Found 2 closest match
# Distance of 0.13687233339366722
# In 2004, a satellite detects a mysterious heat bloom beneath Bouvetøya, an island about one thousand miles off the coast of Antarctica. Wealthy industrialist Charles Bishop Weyland (Lance Henriksen) discovers through thermal imaging that there is a pyramid buried 2000 feet beneath the ice. He attempts to claim it for his multinational communications company, Weyland Industries, a subsidiary of the Weyland Corporation, and assembles a team of experts to investigate. The team includes archaeologists, linguistic experts, drillers, mercenaries, and a guide named Alexa Woods (Sanaa Lathan).
# As a Predator ship reaches Earth's orbit, it fires a beam that creates a passage through the ice towards the source of the heat bloom. When the team arrives at the abandoned whaling station above the heat source, they find the passage and descend beneath the ice. They locate the mysterious pyramid and begin to explore it, finding evidence of a prehistoric civilization and what appears to be a sacrificial chamber filled with human skeletons with ruptured rib cages.
# Meanwhile, three Predators consisting of Scar, Celtic and Chopper arrive and kill all the humans on the surface. They make their way down to the pyramid and arrive just as the team unwittingly activates the structure. The Alien Queen awakes from cryogenic stasis and begins to produce eggs. When the eggs hatch, several facehuggers attach themselves to humans trapped in the sacrificial chamber. Chestbursters emerge from the humans and quickly grow into adult Aliens. Conflict erupts between the Predators, Aliens, and humans, resulting in several deaths. Celtic and Chopper are killed by an Alien, and Weyland buys Alexa and Italian archaeologist Sebastian De Rosa (Raoul Bova) enough time to escape from Scar, giving his life in the process. The two witness Scar kill a facehugger and an Alien with a shuriken before unmasking and marking himself with the blood of the facehugger. After Alexa and Sebastian leave, another facehugger attaches itself to Scar due to him not wearing his mask.
# Through translation of the pyramid's hieroglyphs, Alexa and Sebastian learn that the Predators have been visiting Earth for thousands of years. It was they who taught early human civilizations how to build pyramids, and were worshiped as gods. Every 100 years they visited Earth to take part in a rite of passage by which several humans sacrifice themselves as hosts for the Aliens, creating the "ultimate prey" for the Predators to hunt while being able to survive in the pyramid; if overwhelmed, the Predators would activate a self-destruct device to eliminate the Aliens and themselves. The two deduce that this is why the current Predators are at the pyramid, and that the heat bloom was to attract humans for the sole purpose of making new Aliens to hunt.
# Alexa and Sebastian decide that the Predators must be allowed to succeed in their hunt so that the Aliens do not escape to the surface. Sebastian is captured by an Alien, leaving only Alexa and Scar to fight the Aliens. Scar uses parts of a dead Alien to fashion weapons for Alexa and the two form an alliance. The Queen Alien, using her acid blood, is freed from her restraints and begins pursuing, along with the other Aliens, Alexa and Scar. Just as they are about to escape, they use a self-destruct device to destroy the pyramid and the remaining Aliens. Alexa and Scar reach the surface, however the Alien Queen has survived and continues chasing them. They defeat the Queen by attaching its chain to a water tower and pushing her over a cliff, dragging the Queen to the ocean floor. Scar, however, had been impaled by the Alien Queen's tail and succumbs to his wounds and dies.
# A Predator ship uncloaks and several Predators appear. They retrieve their fallen comrade and an elite Predator presents Alexa with one of their spear weapons as a gift. The other Predators recognize her for her skill as a warrior symbolized by the alien blood Scar burned on her cheek before he died. As the Predators retreat into space, a chestburster with a hybrid form of an Alien and a Predator erupts from Scar's chest.
#
# Found 3 closest match
# Distance of 0.13732226425324456
# In the near future, the unmanned Pilgrim 7 space probe returns from Mars to Earth orbit with soil samples potentially containing evidence of extraterrestrial life. The probe is captured and its samples retrieved by the International Space Station and its six-member crew. Exobiologist Hugh Derry, who is paralyzed from the waist down, revives a dormant cell from the sample, which quickly grows into a multi-celled organism that American school children name "Calvin". Hugh realizes that Calvin's cells can change their specialisation, acting as muscle, sensor, and neuron cells all at once.
# An accident in the lab causes Calvin to become dormant; Hugh attempts to revive Calvin with electric shocks, but Calvin immediately becomes hostile and attacks Hugh, crushing his hand. While Hugh lies unconscious from Calvin's attack, Calvin uses Hugh's electric shock tool to escape its enclosure; now free in the laboratory, Calvin devours a lab rat by absorbing it, growing in size. Engineer Rory Adams enters the lab to rescue Hugh; he is locked in by fellow crew member and physician David Jordan, however, to keep Calvin contained. Calvin latches onto Rory's leg; after Rory unsuccessfully attacks Calvin with a portable rocket thruster, Calvin enters his mouth, devouring his organs from the inside and killing him. Emerging from Rory's mouth even larger, Calvin escapes through a fire-control vent.
# Finding their communication with Earth cut off due to overheating of the communication systems, ISS commander Ekaterina Golovkina performs a space walk to find and fix the problem. She discovers that Calvin has breached the ISS's cooling system; soon after, Calvin attacks her, rupturing her spacesuit's water coolant system in the process and causing the water in the system to fill her suit. She blindly makes her way back to the airlock; however, she and the crew realize that if she re-enters, Calvin will also be able to re-enter the ISS. Hence, she refuses to open the hatch and stops David from helping her do so; this keeps Calvin out of the station for the time being but also causes her to drown and die in her spacesuit.
# Calvin then attempts to re-enter the station through its maneuvering thrusters. The crew try to fire the thrusters to blast Calvin away from the spacecraft, but their attempts fail, using up too much fuel and causing the ISS to enter a decaying orbit where it will burn up in Earth's atmosphere. Pilot Sho Murakami informs the crew that they need to use the station's remaining fuel to get back into a safe orbit, although this allows Calvin to re-enter the station. The crew plan to make Calvin dormant by sealing themselves into one module and venting the atmosphere from the rest of the station.
# After the remaining crew finalize preparations to do so, Hugh enters cardiac arrest. The crew then discover that Calvin has been feeding off of Hugh's paralyzed leg. Calvin attacks the remainder of the crew; Sho seals himself in a sleeping pod. As Calvin attempts to break its glass, David and the quarantine officer Miranda North use Hugh's corpse as bait to lure Calvin away from Sho and trap it in another module to deprive it of oxygen. Having received a distress call prior to the damage to the ISS's communication system, Earth sends a Soyuz spacecraft to the station as a fail-safe plan to push the station into deep space. Believing the Soyuz to be on a rescue mission for the ISS crew, Sho leaves his pod and moves to board it, forcing open its hatch; Calvin then attacks him and the Soyuz crew, causing the craft's docking mechanism to fail and resulting in the capsule crashing into the ISS, killing Sho and the Soyuz crew and causing the ISS to once again enter a decaying orbit.
# The only two remaining survivors, David and Miranda, aware that Calvin could survive re-entry, plan for David to lure Calvin into one of the two remaining escape pods attached to the ISS for David to manually pilot the pod into deep space, isolating Calvin and allowing Miranda to return to Earth in the second pod. David manages to lure Calvin into his pod while Miranda enters her pod; as they simultaneously undock their pods from the ISS, one of the pods hits debris and is damaged, veering off course. In David's pod, Calvin attacks him as he struggles to manually pilot the pod; in Miranda's pod, she records a black box message in case of her death during re-entry informing the world of her colleagues' deaths and not to trust Calvin nor any extraterrestrial life from Mars as well as to destroy Calvin at any cost should he make his way to Earth.
# The two pods separate, one earthbound, the other spiraling away from Earth. The earthbound pod lands in the ocean; two nearby Vietnamese fishermen approach it. As they look into the pod, it is revealed to be David's, the astronaut now encased in a web-like substance. Meanwhile, Miranda's pod's navigation system fails due to damage sustained from the debris, sending her flying away from Earth out of control, much to her horror. On Earth, despite David attempting to warn the fishermen, the fishermen open the pod's hatch. Meanwhile, more boats arrive.
